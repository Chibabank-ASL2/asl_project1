# %%
from google.cloud import aiplatform

print(aiplatform.__version__)
# Out:
# 1.43.0

# %%
from vertexai.generative_models import (
    GenerationConfig,
    GenerativeModel,
    HarmBlockThreshold,
    HarmCategory,
    Image,
    Part,
)

# %%
from typing import Any, Callable, Optional, Tuple, Union

from google.cloud import bigquery
from vertexai.generative_models import (
    ChatSession,
    Content,
    FunctionDeclaration,
    GenerationConfig,
    GenerationResponse,
    GenerativeModel,
    Part,
    Tool,
)
import pandas as pd

# %%
REGION = "us-central1"
PROJECT_ID='qwiklabs-asl-02-9dacbbe2194b'
DATASET_ID="ASL_dataset2"

# %% [markdown]
# ## チャットセッション内にfunction calling 実装

# %%
class ChatAgent:
    def __init__(
        self,
        model: GenerativeModel,
        tool_handler_fn: Callable[[str, dict], Any],
        max_iterative_calls: int = 5,
    ):
        self.tool_handler_fn = tool_handler_fn
        self.chat_session = model.start_chat()
        self.max_iterative_calls = 5

    def send_message(self, message: str) -> GenerationResponse:
        response = self.chat_session.send_message(message)

        # This is None if a function call was not triggered
        if len(response.candidates[0].content.parts) == 1:
            fn_call = response.candidates[0].content.parts[0].function_call
        elif len(response.candidates[0].content.parts) == 2:
            fn_call = response.candidates[0].content.parts[0].function_call or response.candidates[0].content.parts[1].function_call

        num_calls = 0
        # Reasoning loop. If fn_call is None then we never enter this
        # and simply return the response
        while fn_call:
            if num_calls > self.max_iterative_calls:
                break

            # Handle the function call
            fn_call_response = self.tool_handler_fn(
                fn_call.name, dict(fn_call.args)
            )
            num_calls += 1

            # Send the function call result back to the model
            response = self.chat_session.send_message(
                Part.from_function_response(
                    name=fn_call.name,
                    response={
                        "content": fn_call_response,
                    },
                ),
            )

            # If the response is another function call then we want to
            # stay in the reasoning loop and keep calling functions.
            if len(response.candidates[0].content.parts) == 1:
                fn_call = response.candidates[0].content.parts[0].function_call
            elif len(response.candidates[0].content.parts) == 2:
                fn_call = response.candidates[0].content.parts[0].function_call or response.candidates[0].content.parts[1].function_call

        return response

# %% [markdown]
# ## 関数の定義

# %%
# get_table_info_func = FunctionDeclaration(
#     name="get_table_info",
#     description="質問されたら最初にこの関数を呼びます。そして利用可能なBigQuery テーブルとテーブルの説明を取得して、ユーザーの質問に適切に回答できるようにします。",
#     parameters={
#         "type": "object",
#         "properties": {
#             "table_id": {
#                 "type": "string",
#                 "description": "BigQueryテーブルIDです。必ず「1」を渡してください",
#             }
#         },
#     },
# )

# sql_query_func = FunctionDeclaration(
#     name="sql_query",
#     description="SQLクエリを使ってBigQueryから情報を抽出します。",
#     parameters={
#         "type": "object",
#         "properties": {
#             "query": {
#                 "type": "string",
#                 "description": """
#                 BigQuery で実行したときにユーザーの質問に回答するのに役立つ、1 行の SQL クエリ を改行なしで書いてください。 
#                 必ず、すでに取得したテーブルIDでクエリ作成してください。
#                 ただし、カラム名とテーブルIDを指定するときは`カラム名`、`テーブルID`で指定してください。
#                 クエリに問題がある場合は、再度SQLを見直して正しく生成してください。
#                 以下のカラムは絶対にSELECTで出力するようにしてください。[`店番号`,`CIF番号`,`担当者コード`]
#                 """,
#             }
#         },
#         "required": [
#             "query",
#         ],
#     },
# )
# query_tool = Tool(
#     function_declarations=[
#         get_table_info_func,
#         sql_query_func,
#     ],
# )

# %%
get_table_info_func = FunctionDeclaration(
    name="get_table_info",
    description="""
    リスト抽出依頼や質問されたら最初に必ずこの関数を呼びます。そして利用可能なBigQuery テーブルとテーブルの説明、カラムとカラムの説明を取得して、ユーザーの質問に適切に回答できるようにします。
    関数の出力の形式は、各テーブル毎に、テーブルID、テーブルの説明、カラム名、カラムの説明などが辞書形式となったものをリストとして渡します。
    """,
    parameters={
        "type": "object",
        "properties": {},
    },
)

sql_query_func = FunctionDeclaration(
    name="sql_query",
    description="この関数を使用して、銀行の顧客データに関するユーザーの質問に答えます。入力は完全に形成されたSQLクエリである必要があります。",
    parameters={
        "type": "object",
        "properties": {
            "query": {
                "type": "string",
                "description": """
                BigQuery で実行したときにユーザーの質問に回答するのに役立つ、1 行の SQL クエリ を改行なしで書いてください。 
                必ず、すでに取得したテーブルIDでクエリ作成してください。
                テーブルを指定するときは、'tableReference'の'{projectId}.{datasetId}.{tableId}'の形でテーブルIDを渡してください。
                ただし、カラム名とテーブルIDを指定するときはそれぞれ`カラム名`、`テーブルID`で指定してください。
                クエリに問題がある場合は、再度SQLを見直して正しく生成してください。
                """,
            }
        },
        "required": [
            "query",
        ],
    },
)
query_tool = Tool(
    function_declarations=[
        get_table_info_func,
        sql_query_func,
    ],
)

# %%
# get_table_info_func = FunctionDeclaration(
#     name="get_table_info",
#     description="BigQuery テーブルとテーブルの説明を取得して、ユーザーの質問に適切に回答できるようにします。",
#     parameters={
#         "type": "object",
#         "properties": {
#             "table_id": {
#                 "type": "string",
#                 "description": "Fully qualified ID of BigQuery table",
#             }
#         },
#     },
# )

# query_tool = Tool(
#     function_declarations=[
#         get_table_info_func,
#     ],
# )

# %%
client = bigquery.Client()
tables = client.list_tables(f"{PROJECT_ID}.{DATASET_ID}")
table_names = [table.table_id for table in tables]
# print(table_names)

table_id_list=[]
for table_id in table_names:
    table_id_list.append(f"{PROJECT_ID}.{DATASET_ID}.{table_id}")
# print(table_id_list)

# %%
def get_table_info():
    bq_client = bigquery.Client()
    list_table_info=[]
    for table_id in table_id_list:
        list_table_info.append(bq_client.get_table(table_id).to_api_repr())
    return list_table_info

def sql_query(query_str: str):
    bq_client = bigquery.Client()
    try:
        # clean up query string a bit
        query_str = (
            query_str.replace("\\n", "").replace("\n", "").replace("\\", "")
        )
        # print(query_str)
        query_job = bq_client.query(query_str)
        result = query_job.result()
        result = str([dict(x) for x in result])
        return result
    except Exception as e:
        return f"Error from BigQuery Query API: {str(e)}"

# %%
# table_id='qwiklabs-asl-02-9dacbbe2194b.ASL_Dataset.CIF別取引属性_個人'
# bq_client = bigquery.Client()
# a=bq_client.get_table(table_id).to_api_repr()
# a

# %%
get_table_info()
# Out:
# [{'kind': 'bigquery#table',
#   'etag': 'tplajaFF8aymDwCB7QpcQw==',
#   'id': 'qwiklabs-asl-02-9dacbbe2194b:ASL_dataset2.CIF別取引属性_個人',
#   'selfLink': 'https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/ASL_dataset2/tables/CIF別取引属性_個人',
#   'tableReference': {'projectId': 'qwiklabs-asl-02-9dacbbe2194b',
#    'datasetId': 'ASL_dataset2',
#    'tableId': 'CIF別取引属性_個人'},
#   'description': '## テーブル「ＣＩＦ別取引属性_個人」について\n\nこのテーブルは、金融機関における個人顧客ごとの属性情報を保持しています。\n\n**基本情報:**\n\n* データ基準年月：データの基準となる年月\n* 個人_企業番号：顧客に付与された番号\n* 店番号：顧客が所属する支店番号\n* CIF番号：顧客に付与されたCIF番号\n* 世帯番号：顧客が所属する世帯に付与された番号\n\n**顧客情報:**\n\n* 預金者コード：預金者区分を表すコード\n* 業種コード_3桁：顧客の業種を表すコード\n* 融資業種コード：融資における顧客の業種を表すコード\n* 取引先名_カナ：顧客名のカナ表記\n* 取引先名_漢字：顧客名の漢字表記\n* 担当者コード：顧客を担当する担当者コード\n* 年齢_当月末：当月末時点の年齢\n* 年齢_4月1日時点：4月1日時点の年齢\n* 生年月日：顧客の生年月日\n* 性別コード：顧客の性別を表すコード\n* 電話番号：顧客の電話番号\n* 住所コード：顧客の住所を表すコード\n* 同一個人企業番号_ＣＩＦ数計：同一の個人_企業番号を持つCIFの数\n* CIF開設日：CIF開設日\n* CIF閉鎖状況：CIFの閉鎖状況\n* 個人ランク_全店：全店における個人ランク\n* 個人_企業ランク_自店：自店における個人・企業ランク\n* 世帯ランク_全店：全店における世帯ランク\n* 世帯ランク_自店：自店における世帯ランク\n\n**顧客属性情報:**\n\n* 融資先：融資先であるかどうかのフラグ\n* 富裕者区分：富裕層区分\n* 法人オーナー区分：法人オーナー区分\n* フラワー電報先：フラワー電報送付対象者フラグ\n* 企業関連コード：関連企業コード\n* 当行職員：当行職員フラグ\n* 清風会会員：清風会会員フラグ\n* 注意情報登録：注意情報登録フラグ\n* 相続：相続発生フラグ\n* 応対注意：応対注意フラグ\n* 住所確認：住所確認フラグ\n* 電話勧誘等不要：電話勧誘不要フラグ\n* 案内類発送禁止：案内類発送禁止フラグ\n* デビットカード不要：デビットカード不要フラグ\n\n**取引履歴情報:**\n\n* 貸出金_ﾛｰﾝ_住公延滞_3ヶ月内：貸出金・ローン・住宅金融公庫における3ヶ月以内の延滞フラグ\n* 自振延滞_3ヶ月内：自動振替の3ヶ月以内の延滞フラグ\n* ローン申込み否決：ローン申し込み否決フラグ\n* 証券会社取引有無基準年月：証券会社取引有無の基準年月\n* 勤務先情報基準年月：勤務先情報の基準年月\n* 勤務先情報登録区分：勤務先情報登録区分\n* 勤務先区分：勤務先区分\n* 勤務先企業番号：勤務先企業番号\n* 勤務先コスモス２企業コード：勤務先コスモス２企業コード\n* 勤務先社員ローンの提携有無：勤務先社員ローンの提携有無\n* 勤務先企業名：勤務先企業名\n* 年間給振金額_千円：年間給与振込金額（千円単位）\n* 直近6ヶ月間給振金額_千円：直近6ヶ月間の給与振込金額（千円単位）\n* 住所コード変更年月_直近：直近の住所コード変更年月\n* 住所コード変更年月_2回前：2回前の住所コード変更年月\n* 住所コード変更年月_3回前：3回前の住所コード変更年月\n* 住所コード変更年月_4回前：4回前の住所コード変更年月\n* カナ氏名変更年月_直近：直近のカナ氏名変更年月\n* カナ氏名変更年月_2回前：2回前のカナ氏名変更年月\n* 普通預金口座開設日：普通預金口座開設日\n* 全普通預金口座不稼動開始日：全普通預金口座の不稼動開始日\n* 普通預金口座不稼動開始日：普通預金口座の不稼動開始日\n* 普通預金口数計：普通預金口座数\n* 普通預金稼動口数計：稼働中の普通預金口座数\n* 普通預金不稼動口数計：不稼動の普通預金口座数\n* 普通預金不稼動口数１ヶ月：1ヶ月間不稼動の普通預金口座数\n* 普通預金不稼動口数２ヶ月：2ヶ月間不稼動の普通預金口座数\n* 普通預金不稼動口数３－５ヶ月：3-5ヶ月間不稼動の普通預金口座数\n* 普通預金不稼動口数６－１１ヶ月：6-11ヶ月間不稼動の普通預金口座数\n* 普通預金不稼動口数１２ヶ月以上：12ヶ月以上不稼動の普通預金口座数\n* ６ヶ月以内普通預金稼働あり：6ヶ月以内に普通預金口座の稼働ありフラグ\n* 預金預り資産貸出_当月平残あり：預金預り資産貸出の当月平均残高ありフラグ\n* 移管有無：移管有無フラグ\n* 移管年月日：移管年月日\n* 給振または年金：給与振込または年金受取フラグ\n* 給振：給与振込フラグ\n* 年金：年金受取フラグ\n\n**サービス利用状況:**\n\n* ひまわり宣言情報・クレジット新規：ひまわり宣言情報におけるクレジット新規フラグ\n* ひまわり宣言情報・ゴールドカード：ひまわり宣言情報におけるゴールドカード保有フラグ\n* ひまわり宣言情報・クレジット30万円以上：ひまわり宣言情報におけるクレジット利用額30万円以上フラグ\n* 年金予約サービス：年金予約サービス利用フラグ\n* 配当金振込：配当金振込フラグ\n* 国保診療報酬：国民健康保険診療報酬フラグ\n* 社保診療報酬：社会保険診療報酬フラグ\n* 被仕向け振込：被仕向け振込フラグ\n* クレジット：クレジットカード保有フラグ\n* JCBまたはＤＣ会員：JCBまたはDCカード会員フラグ\n* JCBｽｰﾊﾟｰｶｰﾄﾞ：JCBスーパーカード保有フラグ\n* JCB本体エクステージ：JCB本体エクステージカード保有フラグ\n* JCB当行外ｶｰﾄﾞ：JCB当行外カード保有フラグ\n* DCｽｰﾊﾟｰｶｰﾄﾞ：DCスーパーカード保有フラグ\n* JCB本体ザクラス：JCB本体ザクラスカード保有フラグ\n* DC当行外ｶｰﾄﾞ：DC当行外カード保有フラグ\n* アメックス：アメックスカード保有フラグ\n* ダイナース：ダイナースカード保有フラグ\n* 紹介型仲介_ちばぎん証券：紹介型仲介（ちばぎん証券）フラグ\n* その他クレジット：その他クレジットカード保有フラグ\n* 五大公共料金_自振：五大公共料金自動振替フラグ\n* 電気_自振：電気料金自動振替フラグ\n* ガス_自振：ガス料金自動振替フラグ\n* 電話_自振：電話料金自動振替フラグ\n* 水道_自振：水道料金自動振替フラグ\n* NHK_自振：NHK料金自動振替フラグ\n* 税金_自振：税金自動振替フラグ\n* 国税_自振：国税自動振替フラグ\n* 地方税_自振：地方税自動振替フラグ\n* 国民年金_自振：国民年金保険料自動振替フラグ\n* 国民年金基金_自振：国民年金基金自動振替フラグ\n* 保険料_自振：保険料自動振替フラグ\n* 生命保険または損害保険料_自振：生命保険料または損害保険料自動振替フラグ\n* 生命保険料_自振：生命保険料自動振替フラグ\n* 損害保険料_自振：損害保険料自動振替フラグ\n* 生命保険当行契約先：生命保険当行契約先フラグ\n* 損保年金当行契約先：損害保険・年金当行契約先フラグ\n* 火災保険当行契約先：火災保険当行契約先フラグ\n* 県民共済_自振：県民共済自動振替フラグ\n* 公団家賃_自振：公団家賃自動振替フラグ\n* 学費_保育料_自振：学費・保育料自動振替フラグ\n* 定額自動送金_自振：定額自動送金フラグ\n* 総合口座：総合口座保有フラグ\n* 大口定期：大口定期預金保有フラグ\n* スーパー定期_300以上：スーパー定期預金（300万円以上）保有フラグ\n* スーパー定期_300未満：スーパー定期預金（300万円未満）保有フラグ\n* 定期預金２０万以上：定期預金20万円以上保有フラグ\n* 貯蓄預金：貯蓄預金保有フラグ\n* 貯蓄預金基準残高以上：貯蓄預金基準残高以上フラグ\n* 貯蓄預金_40万型：貯蓄預金（40万円型）保有フラグ\n* 貯蓄預金_20万型：貯蓄預金（20万円型）保有フラグ\n* ひまわりまたはつきがけ：ひまわりまたはつきがけ利用フラグ\n* ひまわり：ひまわり利用フラグ\n* つきがけ：つきがけ利用フラグ\n* 自振付積立あり：自動振替付積立ありフラグ\n* 積定自振契約額2万円以上：積立定期自動振替契約額2万円以上フラグ\n* 積定自振増額月契約あり：積立定期自動振替増額月契約ありフラグ\n* 積立定期の年間自振設定額合計：積立定期の年間自動振替設定額合計\n* 積立定期の年間自振引落し額合計：積立定期の年間自動振替引落し額合計\n* 財形預金：財形預金保有フラグ\n* 一般財形：一般財形預金保有フラグ\n* 住宅財形：住宅財形預金保有フラグ\n* 年金財形：年金財形預金保有フラグ\n* 外貨預金：外貨預金保有フラグ\n* NCD：NCD保有フラグ\n* 変動金利定期：変動金利定期預金保有フラグ\n* 投資信託：投資信託保有フラグ\n* ＭＭＦ：MMF保有フラグ\n* 公社債型投信_ＭＭＦ除き：公社債型投資信託（MMF除く）保有フラグ\n* 国内型投信：国内型投資信託保有フラグ\n* 外貨建ＭＭＦ：外貨建てMMF保有フラグ\n* 海外型投信：海外型投資信託保有フラグ\n* 投信積立：投資信託積立フラグ\n* 投信積立の年間自振設定額合計：投資信託積立の年間自動振替設定額合計\n* 投信積立の年間自振引落し額合計：投資信託積立の年間自動振替引落し額合計\n ...
#   'schema': {'fields': [{'name': 'データ基準年月',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '個人_企業番号',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'この項目をキーとして他のテーブルと結合する際は他のテーブル項目の「個人_企業番号」のいずれかと結合する。文字型と数値型があるので、型が違う場合は文字型を数値型に直したうえで結合をする。'},
#     {'name': '店番号',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'この項目をキーとして他のテーブルと結合する際は他のテーブル項目の「店番号、店番、所属店番、元帳店番（ユーザーヘッダー）」のいずれかと結合する。文字型と数値型があるので、型が違う場合は文字型を数値型に直したうえで結合をする。1 : 中央, 2 : 幕張, 3 : 稲毛, 4 : 県庁, 5 : 長洲, 6 : 蘇我, 7 : 我孫子, 8 : 柏, 9 : 野田, 10 : 松戸'},
#     {'name': 'CIF番号',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'この項目をキーとして他のテーブルと結合する際は他のテーブル項目の「ＣＩＦ番号_代表ＣＩＦ、CIF番号、ＣＩＦ番号、CIF、顧客番号（ユーザーヘッダー）、ＣＩＦ番号_7桁、ユーザID」のいづれかと結合する。文字型と数値型があるので、型が違う場合は文字型を数値型に直したうえで結合をする。'},
#     {'name': '世帯番号',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '預金者コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '10 : 個人_10, 20 : 個人_20, 30 : 法人, 40 : 日銀, 50 : 記入, 60 : 公金, 70 : 順公金, 90 : 無記名, '},
#     {'name': '業種コード_3桁',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '10 : 給与所得者, 11 : 会社員・役員, 12 : 公務員・公益法人職員, 90 : その他個人, 91 : 主婦, 92 : 学生, 20 : 自営販売サービス業, 30 : 自営農林漁鉱業, 40 : 自営製造建設業, 50 : 医師, 60 : その他自由業, 70 : , 80 : , 100 : 製造業'},
#     {'name': '融資業種コード_3桁',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '010:肉製品製造業,011:乳製品製造業,012:水産食料品製造業,013:水産缶詰製造業,014:調味料製造業,015:パン・生菓子製造業,016:菓子製造業,017:酒類製造業,018:精米・製粉業,019:その他食料品製造業'},
#     {'name': '取引先名_カナ',
#      'type': 'STRING',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '取引先名_漢字',
#      'type': 'STRING',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '担当者コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '年齢_当月末',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '生年月日未登録（年齢不詳）：999'},
#     {'name': '年齢_4月1日時点',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '4月1日時点の年齢｡但し､翌年の3月までは､同一年齢。 ﾏｲﾅｽとなる場合は0｡ 未登録者は999をｾｯﾄ'},
#     {'name': '生年月日',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '未登録：NULL'},
#     {'name': '性別コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0 : 不明, 1 : 男性, 2 : 女性'},
#     {'name': '電話番号', 'type': 'STRING', 'mode': 'NULLABLE', 'description': ' '},
#     {'name': '住所コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '11桁住所コード（ただし未移行先は7桁住所コード）住所_漢字はＣＩＦ補助属性に保有'},
#     {'name': '同一個人企業番号_ＣＩＦ数計',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '同じ個人企業番号のＣＩＦをｶｳﾝﾄしてｾｯﾄ'},
#     {'name': 'CIF開設日',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': 'CIF閉鎖状況',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦが閉鎖状態なら１をセット     0:未閉鎖 1:閉鎖済'},
#     {'name': '個人ランク_全店',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '001:Ｅで50万未満です。,002:Ｅで50～100万未満です。,003:Ｄで100～200万未満です。,004:Ｄで200～300万未満です。,005:Ｃで300～400万未満です。,006:Ｃで400～500万未満です。,007:Ｂで500～600万未満です。,008:Ｂで600～700万未満です。,009:Ｂで700～800万未満です。,010:Ｂで800～900万未満です。,011:Ｂで900～1千万未満です。,012:Ａで1千万～2千万未満です。,013:Ａで2千万～3千万未満です。,014:Ｓで3千万～4千万未満です。,015:Ｓで4千万～5千万未満です。,016:特Ｓで5千万～6千万未満です。,017:特Ｓで6千万～7千万未満です。,018:特Ｓで7千万～8千万未満です。,019:特Ｓで8千万～9千万未満です。,020:特Ｓで9千万～1億未満です。,021:特Ｓで1億～3億未満です。,022:特Ｓで3億～5億未満です。,023:特Ｓで5億～10億未満です。,024:特Ｓで10億以上です。,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:
ード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '003:組合 004:健保 005:行友会 サークル 006:ＯＢ会 同期会 009:関係会社（含む同族会社）051:代表者（オーナー） 052:代表者（その他） 053:家族・代取家族 054:役員 055:職員099:実質同一債務者その他'},
#     {'name': '当行職員',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:以外 1:当行職員'},
#     {'name': '清風会会員',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:以外 1:清風会会員'},
#     {'name': '注意情報登録',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'セールス支援での注意情報登録がＣＩＦにあれば１をセット（0:なし 1:注意情報あり）'},
#     {'name': '相続',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦに事故コード１２（相続）の設定があれば"１"。上記以外は"０"'},
#     {'name': '応対注意',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦに注意コード３２（応対注意）の設定があれば"１"。上記以外は"０"'},
#     {'name': '住所確認',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦに注意コード４４（住所確認）の設定があれば"1"。上記以外は"０"'},
#     {'name': '電話勧誘等不要',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦに案内類発送禁止＝２（禁止）または普通預金の管理表示３０（電話勧誘等不要）の設定があれば"1"。上記以外は"0"'},
#     {'name': '案内類発送禁止',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦに案内類発送禁止＝２（禁止）または３（ＤＭ不要）または４（ＤＭ中断）のいずれかまたは普通預金、当座預金、定期預金の管理表示２１（案内類発送禁止）の設定があれば"1"。上記以外は"0"'},
#     {'name': 'デビットカード不要',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:不要登録あり'},
#     {'name': '貸出金_ﾛｰﾝ_住公延滞_3ヶ月内',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:３ヵ月以内延滞あり'},
#     {'name': '自振延滞_3ヶ月内',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:３ヵ月以内延滞あり'},
#     {'name': 'ローン申込み否決',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:1997年8月以降のﾛｰﾝ自動審査否決あり'},
#     {'name': '証券会社取引有無基準年月',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '証券会社取引有無をセットした最新の日付'},
#     {'name': '勤務先情報基準年月',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの勤務先情報の更新年月（勤務先情報登録区分が１または２の場合のみ保有）'},
#     {'name': '勤務先情報登録区分',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '１：情報系ＦＢＴ登録、２：給振り、財形データ、３：ＣＩＦその他() （１、２は関連名寄せよりセット。関連名寄せになければＣＩＦの勤務先名をセット）'},
#     {'name': '勤務先区分',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:当行未取引先(ＣＩＦのみある先も含む)､1:融資先､2:預金先'},
#     {'name': '勤務先企業番号',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '勤務先の個人_企業番号'},
#     {'name': '勤務先コスモス２企業コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの勤務先コスモス２企業コード'},
#     {'name': '勤務先社員ローンの提携有無',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの勤務先に社員ローン契約があれば"１"  なし:０'},
#     {'name': '勤務先企業名',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの勤務先企業名'},
#     {'name': '年間給振金額_千円',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの当月から１２ヶ月間分の給振金額合計'},
#     {'name': '直近6ヶ月間給振金額_千円',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの当月から６ヶ月間分の給振金額合計'},
#     {'name': '住所コード変更年月_直近',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの住所が変更された一番直近の年月をセット。データ基準年月の前月と前々月の住所コードを比較して判定。（当月の変更は含まれず、翌月反映）預金者コード１０、２０（個人）を対象。（7桁→11桁の変更を含め住所コードの修正や換地処分等は住所変更とみなされる。）'},
#     {'name': '住所コード変更年月_2回前',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '住所コード変更年月の2番目に新しい年月'},
#     {'name': '住所コード変更年月_3回前',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '住所コード変更年月の3番目に新しい年月'},
#     {'name': '住所コード変更年月_4回前',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '住所コード変更年月の4番目に新しい年月'},
#     {'name': 'カナ氏名変更年月_直近',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦのカナ氏名が変更された一番直近の年月をセット。データ基準年月の前月と前々月を比較して判定。（当月の変更は含まれず、翌月反映）預金者コード１０、２０（個人）を対象。'},
#     {'name': 'カナ氏名変更年月_2回前',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '上記の2番目に新しい年月'},
#     {'name': '普通預金口座開設日',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの中で一番古い普通預金口座開設日をセット'},
#     {'name': '全普通預金口座不稼動開始日',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの全普通預金口座が6ヶ月以上連続不稼動となった日'},
#     {'name': '普通預金口座不稼動開始日',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの普通預金口座の中で１つでも6ヶ月以上連続不稼動となった日'},
#     {'name': '普通預金口数計',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの普通預金口数（閉鎖されていない口座を対象）'},
#     {'name': '普通預金稼動口数計',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの中で当月稼動した口座数（元加は稼動としない）'},
#     {'name': '普通預金不稼動口数計',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの中で当月不稼動の口座数（不稼動口数１～５の合計）'},
#     {'name': '普通預金不稼動口数１ヶ月',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの普通預金口座で不稼動1ヶ月の口座数'},
#     {'name': '普通預金不稼動口数２ヶ月',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの普通預金口座で不稼動2ヶ月の口座数'},
#     {'name': '普通預金不稼動口数３_５ヶ月',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの普通預金口座で3～5ヶ月連続不稼動の口座数'},
#     {'name': '普通預金不稼動口数６_１１ヶ月',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの普通預金口座で6～11ヶ月連続不稼動の口座数'},
#     {'name': '普通預金不稼動口数１２ヶ月以上',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの普通預金口座で12ヶ月以上連続不稼動の口座数'},
#     {'name': '６ヶ月以内普通預金稼働あり',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの普通預金口座の中で6ヶ月以内に稼動した口座があれば"1"。以外"0"'},
#     {'name': '預金預り資産貸出_当月平残あり',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ＣＩＦの預金＋預り資産＋貸出金の平残で判定。（1:月中積数が1円以上の先､0:月中積数が0円の先）'},
#     {'name': '移管有無',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:移管口座なし､1:個別移管あり、2:センター移管あり  （同一店内移管は除く）'},
#     {'name': '移管年月日',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': '移管有無の最新日（最終の移管日）'},
#     {'name': '給振または年金',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり '},
#     {'name': '給振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり '},
#     {'name': '年金',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり '},
#     {'name': 'ひまわり宣言情報_クレジット新規',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり '},
#     {'name': 'ひまわり宣言情報_ゴールドカード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり '},
#     {'name': 'ひまわり宣言情報_クレジット30万円以上',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり '},
#     {'name': '年金予約サービス',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり '},
#     {'name': '配当金振込',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり '},
#     {'name': '国保診療報酬',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり '},
#     {'name': '社保診療報酬',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり '},
#     {'name': '被仕向け振込',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり '},
#     {'name': 'クレジット',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり （ JCBからその他クレジットまでどれか一つでもあれば"１"）'},
#     {'name': 'JCBまたはＤＣ会員',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'JCBｽｰﾊﾟｰｶｰﾄﾞ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '本人契約かつ有効期限が前月末以降かつ退会以外の状態かつ提携先が2401でも0030でもない：1\nその他：0'},
#     {'name': 'JCB本体エクステージ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '本人契約かつ有効期限が前月末以降かつ退会以外の状態かつ提携先=0030：1\nその他：0\n（ＪＣＢ本体・エクステージ）'},
#     {'name': 'JCB当行外ｶｰﾄﾞ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '自振契約コード=025の引落が12ヶ月以内に１回以上ある場合：1\nその他：0'},
#     {'name': 'DCｽｰﾊﾟｰｶｰﾄﾞ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '本人契約かつ有効期限が前月末以降かつ退会以外の状態：1\nその他：0'},
#     {'name': 'JCB本体ザクラス',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '本人契約かつ有効期限が前月末以降かつ退会以外の状態かつ提携先=2401：1\nその他：0\n(JCB本体・ザ・クラス）'},
#     {'name': 'DC当行外ｶｰﾄﾞ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '自振契約コード=026の引落が12ヶ月以内に１回以上ある場合：1\nその他：0'},
#     {'name': 'アメックス',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'ダイナース',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '紹介型仲介_ちばぎん証券',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'その他クレジット',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '五大公共料金_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '電気_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'ガス_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '電話_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '水道_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'NHK_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '税金_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '国税_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '地方税_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '国民年金_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '国民年金基金_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '保険料_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり （生命保険または損害保険のある先またはその他保険料のある先 ）'},
#     {'name': '生命保険または損害保険料_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり  （生命保険または損害保険のある先）'},
#     {'name': '生命保険料_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '損害保険料_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '生命保険当行契約先',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり(営業統括部で受領する保険データにより判定）'},
#     {'name': '損保年金当行契約先',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり(営業統括部で受領する保険データにより判定）'},
#     {'name': '火災保険当行契約先',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり（CIFの管理表示51設定先）'},
#     {'name': '県民共済_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '公団家賃_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '学費_保育料_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '定額自動送金_自振',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '総合口座',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '大口定期',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'スーパー定期_300以上',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'スーパー定期_300未満',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '定期預金２０万以上',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '貯蓄預金',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '貯蓄預金２０万型、４０万型のいずれかがあれば"１"（0:なし 1:あり ）'},
#     {'name': '貯蓄預金基準残高以上',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '貯蓄預金２０万型、４０万型のいずれかが基準残高以上であれば"１"（0:なし 1:あり ）'},
#     {'name': '貯蓄預金_40万型',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '貯蓄預金_20万型',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'ひまわりまたはつきがけ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり （ひまわりまたはつきがけのいずれかがあれば"１"）'},
#     {'name': 'ひまわり',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'つきがけ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '自振付積立あり',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '積定自振契約額2万円以上',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '積定自振増額月契約あり',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '積立定期の年間自振設定額合計',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '積立定期の年間自振設定額を合計'},
#     {'name': '積立定期の年間自振引落し額合計',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '積立定期の年間自振引落し額を合計'},
#     {'name': '財形預金',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '一般、住宅、年金財形のいずれかがあれば"１" （0:なし 1:あり ）'},
#     {'name': '一般財形',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '住宅財形',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '年金財形',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '外貨預金',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'NCD',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '変動金利定期',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '投資信託',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'ＭＭＦ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '公社債型投信_ＭＭＦ除き',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '国内型投信',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '外貨建ＭＭＦ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '海外型投信',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '投信積立',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '投信積立の年間自振設定額合計',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '投信積立の年間自振設定額を合計'},
#     {'name': '投信積立の年間自振引落し額合計',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '投信積立の年間自振引落し額を合計'},
#     {'name': 'VISAデビット',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'キャッシュカード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '信託契約',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり （適格退職年金信託，厚生年金基金信託，土地信託，付随業務信託、本体業務信託(ｺｰﾄﾞﾌﾞｯｸ参照)）'},
#     {'name': 'テレバン',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '※ﾃﾚﾊﾞﾝ廃止に伴い、2023年○月よりデータ連携なし'},
#     {'name': 'インターネットバンキング',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'モバイルバンキング',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '貸金庫',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'セーフティケース',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '県年金',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '国の教育ローン',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '住公_住宅ローン_完済10年含む',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり （住宅ローンにはＬＬローン住宅も含む）'},
#     {'name': '住宅金融公庫',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '住宅ローン',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり （住宅ローンにはＬＬローン住宅を含まず。対象の商品分類コード=(001,002,003,033,101)：住宅ローン、財形住宅ローン、財形給振住宅ローン、あっ旋住宅ローン、社員ローン（住宅））'},
#     {'name': 'つなぎローン',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '不動産ローン',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'ちばぎんＩＤ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'L_Lローン',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'L_Lローン_カードローン',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'L_Lローン_住宅',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'L_Lローンフリー型_その他ロ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '通帳アプリ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'フリーローン',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'マイカーローン',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'リフォームローン',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '教育ローン',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'カードローン',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり\n※ポイントおまとめ先を含め判定'},
#     {'name': 'カードローン20_200',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'カードローン20～200（ｸｲｯｸﾊﾟﾜｰも含まれている）のいずれかがあれば"１"  (0:なし 1:あり)'},
#     {'name': 'カードローンスペシャル',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'カードローン200',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'カードローン100',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'カードローン50',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'カードローン30',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'カードローンワイド',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'カードローンクイックパワー',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '申込型ｶｰﾄﾞﾛｰﾝ_本体クレジット付帯',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり '},
#     {'name': 'NISA口座',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり '},
#     {'name': 'つみたてNISA',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': 'JCBデビット',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり '},
#     {'name': 'ひまわり宣言情報_ステージ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:ブロンズ 2:シルバー\u30003:ゴールド\u3000\n ※ポイントおまとめ先を含め判定'},
#     {'name': 'ひまわり宣言情報_取引項目数',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '※ポイントおまとめ先を含め判定'},
#     {'name': 'ひまわり宣言情報_加算項目数',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '※ポイントおまとめ先を含め判定'},
#     {'name': 'ひまわり宣言情報_都内住宅ローン',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり\n※ポイントおまとめ先を含め判定'},
#     {'name': 'ひまわり宣言情報_INET支店ローン残高',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり\n※ポイントおまとめ先を含め判定'},
#     {'name': 'ひまわり宣言情報_住宅_目的別ローン残高',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり\n※ポイントおまとめ先を含め判定'},
#     {'name': 'ひまわり宣言情報_末残30万以上',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり\n※ポイントおまとめ先を含め判定'},
#     {'name': 'ひまわり宣言情報_カードローン',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり\n※ポイントおまとめ先を含め判定'}]},
#   'numBytes': '60843',
#   'numLongTermBytes': '0',
#   'numRows': '39',
#   'creationTime': '1729556459056',
#   'lastModifiedTime': '1729557886010',
#   'type': 'TABLE',
#   'location': 'US',
#   'numTimeTravelPhysicalBytes': '0',
#   'numTotalLogicalBytes': '60843',
#   'numActiveLogicalBytes': '60843',
#   'numLongTermLogicalBytes': '0',
#   'numTotalPhysicalBytes': '16299',
#   'numActivePhysicalBytes': '16299',
#   'numLongTermPhysicalBytes': '0',
#   'numCurrentPhysicalBytes': '16299'},
#  {'kind': 'bigquery#table',
#   'etag': '4JwH54b5gyUPmj1cmYYMYg==',
#   'id': 'qwiklabs-asl-02-9dacbbe2194b:ASL_dataset2.CRM_交渉履歴',
#   'selfLink': 'https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/ASL_dataset2/tables/CRM_交渉履歴',
#   'tableReference': {'projectId': 'qwiklabs-asl-02-9dacbbe2194b',
#    'datasetId': 'ASL_dataset2',
#    'tableId': 'CRM_交渉履歴'},
#   'description': '## CRM_交渉履歴 テーブルの説明\n\nこのテーブルは、金融機関における顧客との商談履歴に関する情報を格納しています。\n\n**基本情報:**\n\n* 店番: 商談が発生した店舗の番号\n* 交渉履歴対応年月日: 商談が行われた日付\n* 交渉履歴対応時刻: 商談が行われた時間\n* 交渉履歴明細番号: 各商談に一意に付与された番号\n* 交渉履歴登録日: 商談履歴が登録された日付\n* 最終更新店番: 最終更新が行われた店舗の番号\n* 最終更新者番号: 最終更新を行った担当者の番号\n* 最終更新日付: 最終更新が行われた日付\n\n**顧客情報:**\n\n* CIF番号: 顧客に付与されるユニークな番号\n* 店CIF: 店舗に紐づく顧客番号\n* 交渉履歴登録時年齢: 商談時の顧客の年齢\n\n**商談内容:**\n\n* 交渉履歴コメント区分コード: 商談内容に関するコメントの区分を表すコード\n* 交渉チャネルコード: 商談が行われたチャネルを表すコード\n* 交渉チャネル名: 商談が行われたチャネルの名称\n* 交渉履歴登録店番: 商談履歴を登録した店舗の番号\n* 交渉履歴登録者役職名: 商談履歴を登録した担当者の役職名\n* 交渉履歴登録者係番号: 商談履歴を登録した担当者の所属部署の番号\n* 交渉履歴登録者ユーザID: 商談履歴を登録した担当者のユーザーID\n* 交渉履歴登録者名: 商談履歴を登録した担当者の氏名\n* 交渉履歴相手コード: 商談相手の顧客コード\n* 交渉履歴相手: 商談相手の顧客名\n* 交渉履歴同席者名: 商談に同席した人の氏名\n* 交渉履歴面談目的コード: 商談の目的を表すコード\n* 交渉履歴面談目的名: 商談の目的の名称\n* 交渉履歴目的詳細コード: 商談の目的の詳細を表すコード\n* 交渉履歴目的詳細名: 商談の目的の詳細の名称\n* 推奨商品ID: 顧客に推奨した商品のID\n* 商品コード: 商談対象となった商品のコード\n* 商品名: 商談対象となった商品の名称\n* 交渉結果コード: 商談結果を表すコード\n* 交渉結果: 商談結果のテキスト\n* 見込なし理由コード: 商談が見込みなしとなった理由を表すコード\n* 見込なし理由: 商談が見込みなしとなった理由のテキスト\n* 交渉内容: 商談の内容に関するメモ\n* 定型登録種類コード: 定型登録の種類を表すコード\n* 定型登録種類: 定型登録の種類の名称\n\n**フォロー情報:**\n\n* テレバン営業店フォローフラグ: テレバン営業店によるフォローが必要かどうかを示すフラグ\n* テレバン営業店フォロー依頼先店番: テレバン営業店によるフォローを依頼する店舗の番号\n* ビジネスセンター営業店フォローフラグ: ビジネスセンター営業店によるフォローが必要かどうかを示すフラグ\n* ビジネスセンター営業店フォロー依頼先店番: ビジネスセンター営業店によるフォローを依頼する店舗の番号\n\n**その他:**\n\n* 注意情報フラグ: 注意情報があるかどうかを示すフラグ\n* 注意情報詳細コード: 注意情報の内容を表すコード\n* 注意情報詳細: 注意情報の内容\n* 指示事項フラグ: 指示事項があるかどうかを示すフラグ\n* ネタ情報フラグ: ネタ情報があるかどうかを示すフラグ\n* 非公開フラグ: 非公開情報があるかどうかを示すフラグ\n* 非公開詳細コード: 非公開情報の内容を表すコード\n* 非公開詳細: 非公開情報の内容\n* インタビューシートフラグ: インタビューシートがあるかどうかを示すフラグ\n* 役席確認フラグ: 役席による確認が行われたかどうかを示すフラグ\n* 役席コメントフラグ: 役席からのコメントがあるかどうかを示すフラグ\n* 店長確認フラグ: 店長による確認が行われたかどうかを示すフラグ\n* 店長コメントフラグ: 店長からのコメントがあるかどうかを示すフラグ\n* 作成完了フラグ: 作成が完了したかどうかを示すフラグ\n\n## 利用例について\n\n提供されたSQLは、特定の条件（館山市・南房総市・鋸南町在住の個人ランクB以上の顧客）を満たす顧客と、それらの顧客に対する最新の商談日時を抽出するクエリです。\n\n## 想定される依頼\n\n* 特定の商品を推奨した商談の履歴を抽出する。\n* 特定の期間における、新規顧客獲得数の推移を分析する。\n* 商談の成否と、商談内容や担当者との関連性を分析する。\n* 特定の地域における、顧客の属性やニーズを分析する。\n* 優秀な成績を収めている担当者の商談履歴を分析し、成功要因を特定する。',
#   'schema': {'fields': [{'name': '店番',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'この項目をキーとして他のテーブルと結合する際は他のテーブル項目の「店番号、店番、所属店番、元帳店番（ユーザーヘッダー）」のいずれかと結合する。文字型と数値型があるので、型が違う場合は文字型を数値型に直したうえで結合をする。1 : 中央, 2 : 幕張, 3 : 稲毛, 4 : 県庁, 5 : 長洲, 6 : 蘇我, 7 : 我孫子, 8 : 柏, 9 : 野田, 10 : 松戸'},
#     {'name': 'CIF番号',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'この項目をキーとして他のテーブルと結合する際は他のテーブル項目の「ＣＩＦ番号_代表ＣＩＦ、CIF番号、ＣＩＦ番号、CIF、顧客番号（ユーザーヘッダー）、ＣＩＦ番号_7桁、ユーザID」のいづれかと結合する。文字型と数値型があるので、型が違う場合は文字型を数値型に直したうえで結合をする。'},
#     {'name': '店CIF',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '交渉履歴対応年月日',
#      'type': 'TIMESTAMP',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '交渉履歴対応時刻',
#      'type': 'STRING',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '交渉履歴明細番号',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '交渉履歴コメント区分コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '交渉チャネルコード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '01:ＤＭ,02:テレバン,03:窓口(ﾃﾗｰ),04:ｲﾝﾀｰﾈｯﾄ,05:ＡＴＭ,06:Ｍ／Ｂ,11:窓口(営業),12:電話(内部),13:電話(営業),14:ﾒｰﾙｵｰﾀﾞｰ,15:訪問(ﾃﾗｰ),16:訪問(営業),17:督促状等,18:ポータル,19:セミナー,20:その他,21:電話(ﾃﾗｰ),22:窓口(内部),23:窓口(融資),24:電話(融資),25:訪問(融資),26:訪問(内部),27:ﾛｰﾝD(ｲﾝ),28:ﾛｰﾝD(ｱｳﾄ),29:ﾛｰﾝD(郵送),30:タブレット,31:WEB申込,32:ﾀﾌﾞﾚｯﾄ(WEB),:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,'},
#     {'name': '交渉チャネル名',
#      'type': 'STRING',
#      'mode': 'NULLABLE',
#      'description': '交渉チャネルコードに対応したチャネル名'},
#     {'name': '交渉履歴登録店番',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': '1 : 中央, 2 : 幕張, 3 : 稲毛, 4 : 県庁, 5 : 長洲, 6 : 蘇我, 7 : 我孫子, 8 : 柏, 9 : 野田, 10 : 松戸'},
#     {'name': '交渉履歴登録者役職名',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '交渉履歴登録者係番号',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '交渉履歴登録者ユーザID',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '交渉履歴登録者名',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '交渉履歴相手コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '01:本人,02:配偶者,03:家族,04:実権者,05:副実権者,06:従業員,07:その他,1:その他,90:その他,（空欄）orそれ以外:その他,'},
#     {'name': '交渉履歴相手',
#      'type': 'STRING',
#      'mode': 'NULLABLE',
#      'description': '交渉履歴相手コードに対応した交渉履歴の相手'},
#     {'name': '交渉履歴同席者名',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '交渉履歴面談目的コード',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': '01:プロパー融資,02:協会融資,03:住宅ローン,05:その他商品,06:情報収集,07:その他,08:投資型金融商品,09:期日管理,11:集金,16:融資新規,17:深耕,18:電話セールス,19:稟議・協議作成,20:内部事務,21:預金・国債等,（空欄）orそれ以外:その他,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,:,'},
#     {'name': '交渉履歴面談目的名',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': '交渉履歴面談目的コードに対応した面談目的の名称'},
#     {'name': '交渉履歴登録時年齢',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name':
',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0 : 無し\u30001 : あり '},
#     {'name': '注意情報詳細コード',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': '01:事務苦情,02:対応苦情,03:待ち時間苦情,04:その他,05:謝絶,06:代弁等,90:【優良顧客】,（空欄）orそれ以外:その他,'},
#     {'name': '注意情報詳細',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': '注意情報詳細コードに対応した注意情報の詳細'},
#     {'name': '指示事項フラグ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0 : 無し\u30001 : あり '},
#     {'name': 'ネタ情報フラグ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0 : 無し\u30001 : あり '},
#     {'name': '非公開フラグ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0 : 無し\u30001 : あり '},
#     {'name': '非公開詳細コード',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': '1:機微情報,2:準法人関係情報（本部）,3:準法人関係情報（営業店）,4:相続情報（本部）,5:相続情報（営業店）,（空欄）orそれ以外:その他,'},
#     {'name': '非公開詳細',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': '非公開詳細コードに対応した非公開詳細について'},
#     {'name': 'インタビューシートフラグ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0 : 無し\u30001 : あり '},
#     {'name': '役席確認フラグ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0 : 無し\u30001 : あり '},
#     {'name': '役席コメントフラグ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0 : 無し\u30001 : あり '},
#     {'name': '店長確認フラグ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0 : 無し\u30001 : あり '},
#     {'name': '店長コメントフラグ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0 : 無し\u30001 : あり '},
#     {'name': '作成完了フラグ',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0 : 無し\u30001 : あり '},
#     {'name': '最終更新店番',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '1 : 中央, 2 : 幕張, 3 : 稲毛, 4 : 県庁, 5 : 長洲, 6 : 蘇我, 7 : 我孫子, 8 : 柏, 9 : 野田, 10 : 松戸'},
#     {'name': '最終更新者番号',
#      'type': 'STRING',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '最終更新日付',
#      'type': 'TIMESTAMP',
#      'mode': 'NULLABLE',
#      'description': ' '}]},
#   'numBytes': '11595',
#   'numLongTermBytes': '0',
#   'numRows': '39',
#   'creationTime': '1729556466321',
#   'lastModifiedTime': '1729557945966',
#   'type': 'TABLE',
#   'location': 'US',
#   'numTimeTravelPhysicalBytes': '0',
#   'numTotalLogicalBytes': '11595',
#   'numActiveLogicalBytes': '11595',
#   'numLongTermLogicalBytes': '0',
#   'numTotalPhysicalBytes': '5983',
#   'numActivePhysicalBytes': '5983',
#   'numLongTermPhysicalBytes': '0',
#   'numCurrentPhysicalBytes': '5983'},
#  {'kind': 'bigquery#table',
#   'etag': 'qppn89VqveV4se2+NFFgCw==',
#   'id': 'qwiklabs-asl-02-9dacbbe2194b:ASL_dataset2.VISAデビット契約情報',
#   'selfLink': 'https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/ASL_dataset2/tables/VISAデビット契約情報',
#   'tableReference': {'projectId': 'qwiklabs-asl-02-9dacbbe2194b',
#    'datasetId': 'ASL_dataset2',
#    'tableId': 'VISAデビット契約情報'},
#   'description': '## VISAデビット契約情報_日次 テーブルの説明\n\nこのテーブルは、日次ベースのVISAデビット契約情報が格納されています。\n\n**基本情報:**\n\n* データ基準年月日：データの基準となる年月日\n* 店番：契約店を識別する番号\n* 契約番号：各契約に割り当てられたユニークな番号\n* 科目：口座の種類を示す科目\n* 口座番号：契約に紐づく口座番号\n* ブランドID：カードブランドを識別するID\n* 券面コード：カードの種類を表すコード\n* 入会データ作成日：入会データが作成された日付\n* 入会時受付連番：入会時の受付順を示す連番\n* 契約日：契約が成立した日付\n* 解約日：契約が解約された日付 (解約されていない場合は "00000000")\n* 契約情報変更日：契約情報が最後に変更された日付\n* 当初契約番号：最初に契約した際の契約番号\n\n**顧客情報:**\n\n* CIF：顧客を識別するユニークな番号\n* 個人企業番号：個人または企業を識別する番号\n* 世帯番号：顧客が所属する世帯を識別する番号\n* 顧客番号：顧客を識別するユニークな番号\n* 郵便番号：顧客の郵便番号\n* 住所カナ：顧客の住所をカナで表記\n* 住所漢字：顧客の住所を漢字で表記\n* 住所カナ2：顧客の住所2をカナで表記 (例: マンション名)\n* 住所漢字2：顧客の住所2を漢字で表記 (例: マンション名)\n* 電話番号：顧客の固定電話番号\n* 携帯電話番号：顧客の携帯電話番号\n* 登録情報変更日：顧客の登録情報が最後に変更された日付\n* 個人_法人カード区分：カードが個人向けか法人向けかを区分\n\n**利用限度額:**\n\n* 利用限度額_国内ショッピング1回：国内ショッピング1回あたりの利用限度額\n* 利用限度額_国内ショッピング1日：国内ショッピング1日あたりの利用限度額\n* 利用限度額_国内ショッピング1ヶ月：国内ショッピング1ヶ月あたりの利用限度額\n* 利用限度額_海外ショッピング1回：海外ショッピング1回あたりの利用限度額\n* 利用限度額_海外ショッピング1日：海外ショッピング1日あたりの利用限度額\n* 利用限度額_海外ショッピング1ヶ月：海外ショッピング1ヶ月あたりの利用限度額\n* 利用限度額_海外現金引出1回：海外現金引出1回あたりの利用限度額\n* 利用限度額_海外現金引出1日：海外現金引出1日あたりの利用限度額\n* 利用限度額_海外現金引出1ヶ月：海外現金引出1ヶ月あたりの利用限度額\n\n**利用例:**\n\n過去依頼文とSQL文は、特定の条件 (Visaプラチナデビット保有者で、特定の支店に所属し、解約していない顧客) を満たす顧客を抽出する例を示しています。\n\n**想定される依頼:**\n\n* 特定期間に入会した顧客の属性分析 (年齢層、地域分布など)\n* 特定の利用限度額を超える顧客の抽出\n* 解約率の高い顧客セグメントの分析\n* 住所変更履歴の確認\n*  विभिन्न カードブランドの利用状況比較\n* 入会から一定期間経過した顧客へのフォローアップリスト作成\n\nこのテーブルは、顧客属性、契約情報、利用限度額などの情報を網羅しており、顧客分析、マーケティング、リスク管理など、様々な業務で活用できます。',
#   'schema': {'fields': [{'name': 'データ基準年月',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '店番',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'この項目をキーとして他のテーブルと結合する際は他のテーブル項目の「店番号、店番、所属店番、元帳店番（ユーザーヘッダー）」のいずれかと結合する。文字型と数値型があるので、型が違う場合は文字型を数値型に直したうえで結合をする。1 : 中央, 2 : 幕張, 3 : 稲毛, 4 : 県庁, 5 : 長洲, 6 : 蘇我, 7 : 我孫子, 8 : 柏, 9 : 野田, 10 : 松戸'},
#     {'name': 'CIF',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'この項目をキーとして他のテーブルと結合する際は他のテーブル項目の「ＣＩＦ番号_代表ＣＩＦ、CIF番号、ＣＩＦ番号、CIF、顧客番号（ユーザーヘッダー）、ＣＩＦ番号_7桁、ユーザID」のいづれかと結合する。文字型と数値型があるので、型が違う場合は文字型を数値型に直したうえで結合をする。'},
#     {'name': '個人企業番号',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'この項目をキーとして他のテーブルと結合する際は他のテーブル項目の「個人_企業番号」のいずれかと結合する。文字型と数値型があるので、型が違う場合は文字型を数値型に直したうえで結合をする。'},
#     {'name': '世帯番号',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '顧客番号',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '契約番号',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '郵便番号', 'type': 'STRING', 'mode': 'NULLABLE', 'description': ' '},
#     {'name': '住所カナ', 'type': 'STRING', 'mode': 'NULLABLE', 'description': ' '},
#     {'name': '住所漢字', 'type': 'STRING', 'mode': 'NULLABLE', 'description': ' '},
#     {'name': '住所カナ2',
#      'type': 'STRING',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '住所漢字2',
#      'type': 'STRING',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '電話番号', 'type': 'STRING', 'mode': 'NULLABLE', 'description': ' '},
#     {'name': '携帯電話番号',
#      'type': 'STRING',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '登録情報変更日',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '科目',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '1 : 普通預金, 2 : 当座預金, 3 : 定期預金, 4 : 通知預金, 5 : 積立定期預金, 6 : 別段預金, 10 : Ｃ\u3000Ｉ\u3000Ｆ'},
#     {'name': '口座番号',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': 'ブランドID',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '券面コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '1 一般、2 ゴールド、3 プラチナ'},
#     {'name': '利用限度額_国内ショッピング1回',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '利用限度額_国内ショッピング1日',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '利用限度額_国内ショッピング1ヶ月',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '利用限度額_海外ショッピング1回',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '利用限度額_海外ショッピング1日',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '利用限度額_海外ショッピング1ヶ月',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '利用限度額_海外現金引出1回',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '利用限度額_海外現金引出1日',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '利用限度額_海外現金引出1ヶ月',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '入会データ作成日',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '入会時受付連番',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '契約日',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '契約した年月日を8桁で表示'},
#     {'name': '解約日',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '解約した年月日を8桁で表示'},
#     {'name': '契約情報変更日',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '契約情報を変更した年月日を8桁で表示'},
#     {'name': '個人_法人カード区分',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '当初契約番号',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '}]},
#   'numBytes': '12420',
#   'numLongTermBytes': '0',
#   'numRows': '39',
#   'creationTime': '1729554988095',
#   'lastModifiedTime': '1729557973985',
#   'type': 'TABLE',
# ...
#     {'name': 'スプレッド乖離幅_10万倍',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': 'スプレッド階層コード1',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '001 : 1.0％超, 002 : 0.9％超1.0％以下 , 003 : 0.8％超0.9％以下 , 004 : 0.7％超0.8％以下 , 005 : 0.6％超0.7％以下'},
#     {'name': 'スプレッド階層コード2',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '001 : 1.500％超, 002 : 1.375％超1.500％以下, 003 : 1.250％超1.375％以下, 004 : 1.125％超1.250％以下, 005 : 1.000％超1.125％以下'},
#     {'name': '評価基準利率_10万倍',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '規制_自由金利区分',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:区分なし  1:規制  2:自由'},
#     {'name': '流動_変動_固定区分',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '10:通常貸出（固定金利）\n11:通常貸出（フルスライド金利）\n12:通常貸出（なまくら変動金利）\n23:市場金利連動貸出（クーポン型）\n24:市場金利連動貸出（歩留型）\n50:固定性資産・負債\n60:流動性資産・負債\n99:その他'},
#     {'name': '利率変動区分',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '000:区分なし001:固定003:固定スプレッド006:変動フルスライド（証貸型）007:変動フルスライド(当貸型）009:変動随時010:変動スプレッド\u3000固定金利か変動金利かを調べるときに使います。'},
#     {'name': 'フルスライド種別',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '1 : センタ－一括処理, 2 : 営業店個別処理, 3 : センタ－一括処理(加算あり）, 4 : 営業店個別処理（加算あり）, '},
#     {'name': 'ベースレート区分',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '1 : 短期プライム, 2 : , 3 : 長期プライム, 4 : 新長期プライム（中期）, 5 : 新長期プライム（長期）, 10 : コール, 11 : 手形, 12 : ＮＣＤ, 13 : 債券現先, 14 : 自由金利定期, 15 : , 28 : ＲＦＲ複利（後決め）, 29 : ターム物ＲＦＲ金利（スワップ）, 30 : ターム物ＲＦＲ金利（先物）, 31 : ＬＩＢＯＲ, 32 : ＴＩＢＯＲ, 33 : 円円スワップ, 34 : 市場金利（その他）, 35 : , 50 : ﾛｰﾝ基準金利・変動金利・住宅ﾛｰﾝ, 51 : ﾛｰﾝ基準金利・変動金利・ｱﾊﾟｰﾄﾛｰﾝ他, 55 : ﾛｰﾝ基準金利・金利選択型固定金利･住宅ﾛｰﾝ, 56 : ﾛｰﾝ基準金利･金利選択型固定金利･ｱﾊﾟｰﾄﾛｰﾝ他, 60 : 長期プライム（当貸）, 61 : , 62 : 短期プライム（当貸）, 70 : 変動ｶｰﾄﾞﾛｰﾝ(長期ﾌﾟﾗｲﾑ)年２回用, 71 : 変動旧型ワイド年１回用, 72 : 変動ｶｰﾄﾞﾛｰﾝ(短期ﾌﾟﾗｲﾑ)年２回用, 73 : 変動ｶｰﾄﾞﾛｰﾝ(新長期ﾌﾟﾗｲﾑ)年２回用, 80 : 変動金利ﾛｰﾝ年１回実行用, 81 : 変動金利ﾛｰﾝ年１回見直し用, 82 : 変動金利ﾛｰﾝ長期ﾌﾟﾗｲﾑ年２回用, 83 : 変動金利ﾛ-ﾝ新長期ﾌﾟﾗｲﾑ年２回用(不動産), 84 : 変動金利ﾛ-ﾝ新長期ﾌﾟﾗｲﾑ年２回用(住宅型), 85 : 金利選択固定型（住宅ﾛｰﾝ), 86 : 金利選択固定型（ｱﾊﾟｰﾄ・ｾｶﾝﾄﾞﾊｳｽ-ﾛｰﾝ), 88 : 個別対応, 89 : フリー, 90 : その他, '},
#     {'name': 'ベースレート期間',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ベースレート適用期間'},
#     {'name': 'ベースレート期間単位',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'ベースレート適用期間の単位（１：日，２：週，３：月，４：年）ｵﾝﾗｲﾝｺｰﾄﾞﾌﾞｯｸ（融資共通）・期間単位'},
#     {'name': '長短区分コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '1 : 短期（１年未満）, 2 : 中期（３年未満）, 3 : 中長期（５年未満）, 4 : 長期（１５年未満）, 5 : 超長期（１５年以上）,'},
#     {'name': '約定期間コード_月ベース',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '（期日なし：999）'},
#     {'name': '約定期間コード_年ベース',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': '000:期日なし\n001:３年以内\n002:３年超５年以内\n003:5年超7年以内\n004:7年超１０年以内\n005:10年超'},
#     {'name': '約定期間コード2_年ベース',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '実行起算日から期日までの年数'},
#     {'name': '残存期間コード_月ベース',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'データ基準年月の月末から期日までの月数をセット （期落ちなし:999）'},
#     {'name': '残存期間コード_年ベース',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': '00:期落ちなし\n01:3ヵ月以内\n02:3ヵ月超6ヵ月以内\n03:6ヵ月超1年以内\n04:1年超2年以内\n05:2年超3年以内\n06:3年超5年以内\n07:5年超7年以内\n08:7年超10年以内\n09:10年超（期落ちなしを除く）'},
#     {'name': '残存期間コード2_年ベース',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 
用保証協会, 25 : （財）不動産流通推進センター, 26 : 日本酒造組合中央会保証, 27 : 日栄ファイナンス（株）, 28 : 情報処理振興事業協会, 29 : 埼玉県信用保証協会, 30 : 茨城県農業信用基金協会保証, 31 : 神奈川県信用保証協会保証, 32 : 川崎市信用保証協会保証, 33 : （財）建設業振興基金保証, 34 : （独）石油ガス金属鉱物資源機構, 35 : （財）産廃処理事業振興財団, 36 : （独）中小企業基盤整備機構, 37 : （独）日本貿易保険, 38 : （株）国際協力銀行, 39 : （株）東日本震災支援機構, 41 : 東日本建設業保証（株）, 42 : 有配保証＿プライム, 43 : 有配保証＿スタンダード、プレミア, 44 : 金融機関, 45 : 国・地方公共団体, 50 : 住宅融資保険, 58 : 提携先保証, 59 : 個人信用保険, 60 : 日本興亜損害保険（株）, 61 : 東京海上火災保険（株）, 62 : 三井住友海上火災保険（株）\u3000（旧住友）, 63 : 三井住友海上火災保険（株）\u3000（旧三井）, 64 : 日動火災海上保険（株）, 69 : その他損保会社, 70 : ちばぎん保証（株）, 71 : 地銀共同保証（株）, 72 : 不動産信用保証（株）, 73 : ちばぎん保証（株）（無担保口）, 74 : 日栄ファイナンス（株）, 75 : 日本信販（株）, 76 : オリエントコーポレーション（株）, 77 : （株）アプラス, 78 : （株）ジャックス, 80 : エム・ユー信用保証（株）, 83 : （株）クレディセゾン, 84 : ちばぎん保証（日栄口）, 85 : 全国保証（株）, 89 : その他保証会社, 99 : ,'},
#     {'name': '信用補完名_漢字',
#      'type': 'STRING',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '保証形式区分',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '１：保証書（確定債務保証），２：保証書（限度保証），３：手形保証（確定債務保証），４：契約書保証（確定債務保証），５：その他'},
#     {'name': '提携先コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '消費者ローンの提携先（ﾛｰﾝｺｰﾄﾞ･提携先ｺｰﾄﾞ一覧表参照）'},
#     {'name': '提携先名_漢字',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '提携区分',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:非提携 1:提携'},
#     {'name': '極度区分',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '裁量コード=3または4なら１  以外は０'},
#     {'name': '商手一括_明細区分',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '商手のみ（０：一括，１：個別）'},
#     {'name': '手形枚数',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '商手の一括実行した時の手形枚数'},
#     {'name': '支払承諾残高_円',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '支払承諾_保証割合',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '支払承諾_保証利率_10万倍',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '支払承諾_保証料受入方法',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '1 : 先払い, 2 : 後払い, 3 : 保証料計算なし, '},
#     {'name': '代理貸付_手数料率_10万倍',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '代理貸付_手数料受入方法',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '1 : 随時受入方式, 2 : 一括請求方式（年金福祉２号資金）, 3 : 一括請求方式（年金福祉３号資金）, 4 : 手数料受入なし, '},
#     {'name': '代位弁済コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '支払コードが０以外のとき、代弁コード\n支払コードが０のとき、開始回数として使用。'},
#     {'name': '延滞区分コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '月末基準で延滞しているか否かのフラグ（０：正常，１：延滞）'},
#     {'name': '未収区分コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '月末基準で未収利息が発生しているか否かのフラグ（０：正常，１：未収）'},
#     {'name': '延滞月数区分',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:値なし 1:1ヵ月 2:2ヵ月 3:3ヵ月 4:4～6ヵ月 5:7～12ヵ月 6:13ヵ月以上'},
#     {'name': '当月延滞有り',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0:なし 1:あり'},
#     {'name': '延滞日数',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '累積延滞日数',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '貸出開始からの累積日数'},
#     {'name': '累積延滞発生回数',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '貸出開始からの延滞発生回数(下記区分の合計値)'},
#     {'name': '延滞日数区分別累積回数01_10',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '延滞日数区分別累積回数1(1～10日)'},
#     {'name': '延滞日数区分別累積回数11_20',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '延滞日数区分別累積回数2(11～20日)'},
#     {'name': '延滞日数区分別累積回数21_30',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '延滞日数区分別累積回数3(21～30日)'},
#     {'name': '延滞日数区分別累積回数31_61',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '延滞日数区分別累積回数4(31日～)'},
#     {'name': '延滞日数区分別累積回数62_',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '延滞日数区分別累積回数5(62日～)'},
#     {'name': '更改管理コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'カードローンスペシャルの更改停止に使用  1:更改停止   0:以外'},
#     {'name': 'オートコール不要表示',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '当貸管理表示３７ビットまたは融資基本の管理表示３７ビット目がオンなら１'},
#     {'name': '持込業者コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '消費者ローンで使用'},
#     {'name': '申込受付店',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '1 : 中央, 2 : 幕張, 3 : 稲毛, 4 : 県庁, 5 : 長洲, 6 : 蘇我, 7 : 我孫子, 8 : 柏, 9 : 野田, 10 : 松戸'},
#     {'name': '本部実行表示',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '当貸管理表示の6ビット目で判定\n1:本部実行  0:営業店実行'},
#     {'name': '本部集中表示',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '当貸の本部集中表示で判定\n1:本部集中  0:未済'},
#     {'name': '債権証書類本部集中コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '本部集中しているか否かのフラグ\n（０：非本部集中，１：本部集中，２：本部集中（火災保険を除く）'},
#     {'name': '金利感応区分',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': 'カード発行手数料未徴求表示',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '１：当座貸越のカード発行手数料が徴求済み ０：未済'},
#     {'name': '商品コード_収益',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '収益科目コード'},
#     {'name': '営業店収益_円',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '月中収益_銭÷100'},
#     {'name': 'ベーシス収益_円',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '収益スプレッド_10万倍',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '収益スプレッド_10万倍'},
#     {'name': 'ベーシス収益スプレッド_10万倍',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': 'みなし引当_月末日_円',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '末日_ＥＬ_銭÷100'},
#     {'name': 'みなし引当_月累計_円',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '月中_ＥＬ_銭÷100'},
#     {'name': 'デフォルト率1_円',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '末日_ＥＬ_率（10万倍）'},
#     {'name': 'デフォルト率2_円',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '末日_ＵＬ_率（10万倍）'},
#     {'name': '回収可能額_円',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '保全額'},
#     {'name': '回収可能額積数_円',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '月中保全額積数'},
#     {'name': '平均残存期間',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0セット'},
#     {'name': '延滞月数',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': 'マチュリティー（100倍）'},
#     {'name': '固定金利期間終了日',
#      'type': 'FLOAT',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '資金月中利息積数_円',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '月中_仕切利息_銭÷100'},
#     {'name': '約定利率適用日',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '利率適用日'},
#     {'name': '実勢期中残高積数_円',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0セット'},
#     {'name': '経過期中利息積数_円',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0セット'},
#     {'name': '資金期中利息積数_円',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0セット'},
#     {'name': '経過利息基数',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '末日_利息_銭÷100\n（旧収益管理は年換算（×365）で保有）'},
#     {'name': '資金利息基数',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '末日_仕切利息_銭÷100\n（旧収益管理は年換算（×365）で保有）'},
#     {'name': '生保番号',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '裁量コード_付属_極度',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '000:値なし  001:裁量外  002:裁量内  003:稟議（裁量内）  004:裁量内（稟議先）  009:ローン極度扱い\n※※明細単位の裁量コード。極度レコードは裁量コードが一律ゼロであることに対応し、申請情報より編集した値を保有する。取扱番号（明細）単位でなくＣＩＦ単位で使用する場合は「裁量コード」と併用すること。'},
#     {'name': 'カードローン利用限度額_円',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': ' '},
#     {'name': '債権譲渡日', 'type': 'FLOAT', 'mode': 'NULLABLE', 'description': ' '},
#     {'name': '債権買戻日', 'type': 'FLOAT', 'mode': 'NULLABLE', 'description': ' '},
#     {'name': '負担金コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '1 : 負担金対象外, 2 : 負担金対象, 9 : 負担金計測対象, '},
#     {'name': '保証料コード',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0 : 一括前払い０.２％, 1 : 金利内包０.１５％, 2 : 金利内包０.２％, 3 : 金利内包０.３％, 4 : 金利内包０.４％, 5 : 一括前払い０.１％, 6 : , 7 : , 8 : 金利内包０.０８％, 9 : 金利内包型（利息元加約変）, '},
#     {'name': '自然災害時特約支援付',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0 : なし, 1 : あり'},
#     {'name': '先進医療特約あり',
#      'type': 'INTEGER',
#      'mode': 'NULLABLE',
#      'description': '0 : なし, 1 : あり'}]},
#   'numBytes': '56172',
#   'numLongTermBytes': '0',
#   'numRows': '39',
#   'creationTime': '1729556512250',
#   'lastModifiedTime': '1729573498014',
#   'type': 'TABLE',
#   'location': 'US',
#   'numTimeTravelPhysicalBytes': '0',
#   'numTotalLogicalBytes': '56172',
#   'numActiveLogicalBytes': '56172',
#   'numLongTermLogicalBytes': '0',
#   'numTotalPhysicalBytes': '34421',
#   'numActivePhysicalBytes': '34421',
#   'numLongTermPhysicalBytes': '0',
#   'numCurrentPhysicalBytes': '34421'}]

# %%
def handle_query_fn_call(fn_name: str, fn_args: dict):
    """Handles query tool function calls."""
    print(f"Function calling: {fn_name} with args: {str(fn_args)}\n")
    
    if fn_name == "get_table_info":
        result = get_table_info()
    elif fn_name == "sql_query":
        result = sql_query(fn_args["query"])
    else:
        raise ValueError(f"Unknown function call: {fn_name}")
    
    return result

# %%
safety_settings = {
    HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
}

# %%
model = GenerativeModel(
    "gemini-1.5-pro",
    tools=[query_tool],
    generation_config=GenerationConfig(temperature=0.0),
    safety_settings=safety_settings
)

# %%
chat = ChatAgent(model=model, tool_handler_fn=handle_query_fn_call)
# Insert an initialization prompt before the first chat to help guide model behavior and output style/format

init_prompt = """
    質問には簡潔でわかりやすい回答をお願いします。
    最初に必ずBigQueryからテーブルの情報を入手してください。
    BigQuery テーブルをクエリして得た情報のみを使用してください。
    情報を捏造しないでください。
    テーブル名、カラム名を指定するときは必ず「` `」で挟んでください。
    
    以下のルールでBigQueryテーブルを操作します。
    1.`名寄せ取引属性_日次以外`のテーブルに関する情報が必要なときは、必要なテーブルのカラム名:`個人_企業番号`を紐づけてjoinしてください
    2.日付に関するカラムのデータを操作する際は、date型に直して操作してください。
    3.抽出する顧客の出力項目は、「店番号_代表ＣＩＦ」「ＣＩＦ番号_代表ＣＩＦ」「取引先名_漢字_代表ＣＩＦ」「年齢_当月末_代表ＣＩＦ」「電話番号_代表ＣＩＦ」。
    Question:
"""
# 1.テーブル名：名寄せ取引属性_日次以外のテーブルに関する情報が必要なときは、必要なテーブルのカラム名:`個人_企業番号`を紐づけてjoinしてください
# 1、クエリの書き出しは'SELECT DISTINCT T1.`担当者コード_代表ＣＩＦ` ,T1.`個人_企業番号`FROM `qwiklabs-asl-02-9dacbbe2194b.ASL_Dataset.名寄せ取引属性_日次` AS T1'とします。
# 1.最初にテーブル名：CIF別取引属性_個人ではなくテーブル名：名寄せ取引属性_日次から、SELECT DISTINCTで2つのカラム名1：個人企業番号、カラム名2:担当者コード_代表ＣＩＦをとってきてください。
# 1.最初にテーブル名：CIF別取引属性_個人ではなくテーブル名：名寄せ取引属性_日次からカラム名:個人_企業番号、だけだなくカラム名：担当者コードをとってきてください。
# 2.ATMの手数料に関する情報が必要なときは、{テーブル名:'チャネル別利用状況',カラム名:`個人_企業番号`}を紐づけてjoinしてください
# 2.抽出する顧客の出力項目は、「店番号_代表ＣＩＦ」「ＣＩＦ番号_代表ＣＩＦ」「取引先名_漢字_代表ＣＩＦ」「年齢_当月末_代表ＣＩＦ」「電話番号_代表ＣＩＦ」。
prompt = """
中央支店の変動金利貸出の債権ごとのリストをいただけますでしょうか。
"""
response = chat.send_message(init_prompt + prompt)
print(response.text)
# Out:
# Function calling: get_table_info with args: {}
#
# 中央支店の変動金利貸出の債権リストは、`融資ローン元帳`テーブルの`利率変動区分`カラムで判定できます。\
# `融資ローン元帳`テーブルには、`店番号`カラムはありますが、支店名は存在しません。\
# 恐れ入りますが、中央支店がどの`店番号`に該当するかは情報がありません。

# %%
response.candidates[0].content.parts[0].function_call or response.candidates[0].content.parts[1].function_call

# %%
chat.chat_session.history

# %%
response = chat.send_message(
    "はい、8月でお願いします"
)
print(response.text)

# %%
# %%bigquery
# SELECT `取引先名_漢字`, `店番号`, `CIF番号` FROM `qwiklabs-asl-02-9dacbbe2194b.ASL_Dataset.CIF別取引属性_個人` WHERE `取引先名_漢字` LIKE "%人間%"

# %%
chat.chat_session.history
# Out:
# [role: "user"
#  parts {
#    text: "\n    \350\263\252\345\225\217\343\201\253\343\201\257\347\260\241\346\275\224\343\201\247\343\202\217\343\201\213\343\202\212\343\202\204\343\201\231\343\201\204\345\233\236\347\255\224\343\202\222\343\201\212\351\241\230\343\201\204\343\201\227\343\201\276\343\201\231\343\200\202\n    BigQuery \343\203\206\343\203\274\343\203\226\343\203\253\343\202\222\343\202\257\343\202\250\343\203\252\343\201\227\343\201\246\345\276\227\343\201\237\346\203\205\345\240\261\343\201\256\343\201\277\343\202\222\344\275\277\347\224\250\343\201\227\343\201\246\343\201\217\343\201\240\343\201\225\343\201\204\343\200\202\n    \346\203\205\345\240\261\343\202\222\346\215\217\351\200\240\343\201\227\343\201\252\343\201\204\343\201\247\343\201\217\343\201\240\343\201\225\343\201\204\343\200\202\343\202\257\343\202\250\343\203\252\343\202\222\344\275\234\346\210\220\343\201\231\343\202\213\345\211\215\343\201\253\343\200\201\345\277\205\343\201\232\343\201\251\343\201\256\
#    text: "\343\201\212\345\275\271\343\201\253\347\253\213\343\201\246\343\201\232\347\224\263\343\201\227\350\250\263\343\201\202\343\202\212\343\201\276\343\201\233\343\202\223\343\201\214\343\200\201\345\277\205\350\246\201\343\201\252\346\203\205\345\240\261\343\202\222\345\220\253\343\202\200\343\203\206\343\203\274\343\203\226\343\203\253\343\201\214\343\201\202\343\202\212\343\201\276\343\201\233\343\202\223\343\200\202"
#  }]

# %%
response = chat.send_message("""

"""
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ResponseValidationError                   Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 response = chat.send_message(
#       2     "名前に人間が含まれる先の"
#       3 )
#       4 print(response.text)
#
# Cell In[138], line 13, in ChatAgent.send_message(self, message)
#      12 def send_message(self, message: str) -> GenerationResponse:
# ---> 13     response = self.chat_session.send_message(message)
#      15     # This is None if a function call was not triggered
#      16     fn_call = response.candidates[0].content.parts[0].function_call
#
# File ~/.local/lib/python3.10/site-packages/vertexai/generative_models/_generative_models.py:727, in ChatSession.send_message(self, content, generation_config, safety_settings, tools, stream)
#     720     return self._send_message_streaming(
#     721         content=content,
#     722         generation_config=generation_config,
#     723         safety_settings=safety_settings,
#     724         tools=tools,
#     725     )
#     726 else:
# --> 727     return self._send_message(
#     728         content=content,
#     729         generation_config=generation_config,
#     730         safety_settings=safety_settings,
#     731         tools=tools,
#     732     )
#
# File ~/.local/lib/python3.10/site-packages/vertexai/generative_models/_generative_models.py:822, in ChatSession._send_message(self, content, generation_config, safety_settings, tools)
#     820 # By default we're not adding incomplete interactions to history.
#     821 if self._response_validator is not None:
# --> 822     self._response_validator(
#     823         response=response,
#     824         request_contents=request_history,
#     825         response_chunks=[response],
#     826     )
#     828 # Adding the request and the first response candidate to history
#     829 response_message = response.candidates[0].content
#
# File ~/.local/lib/python3.10/site-packages/vertexai/generative_models/_generative_models.py:658, in _validate_response(response, request_contents, response_chunks)
#     648 if candidate.finish_reason not in _SUCCESSFUL_FINISH_REASONS:
#     649     message = (
#     650         "The model response did not completed successfully.\n"
#     651         f"Finish reason: {candidate.finish_reason}.\n"
#    (...)
#     656         "Note that letting blocked or otherwise incomplete responses into chat history might lead to future interactions being blocked by the service."
#     657     )
# --> 658     raise ResponseValidationError(
#     659         message=message,
#     660         request_contents=request_contents,
#     661         responses=response_chunks,
#     662     )
#
# ResponseValidationError: The model response did not completed successfully.
# Finish reason: 3.
# Finish message: .
# Safety ratings: [category: HARM_CATEGORY_HATE_SPEECH
# probability: NEGLIGIBLE
# , category: HARM_CATEGORY_DANGEROUS_CONTENT
# probability: MEDIUM
# blocked: true
# , category: HARM_CATEGORY_HARASSMENT
# probability: NEGLIGIBLE
# , category: HARM_CATEGORY_SEXUALLY_EXPLICIT
# probability: NEGLIGIBLE
# ].
# To protect the integrity of the chat session, the request and response were not added to chat history.
# To skip the response validation, specify `model.start_chat(response_validation=False)`.
# Note that letting blocked or otherwise incomplete responses into chat history might lead to future interactions being blocked by the service.
