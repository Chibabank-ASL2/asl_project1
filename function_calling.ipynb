# %%
from google.cloud import aiplatform

print(aiplatform.__version__)
# Out:
# 1.43.0

# %%
from typing import Any, Callable, Optional, Tuple, Union

from google.cloud import bigquery
from vertexai.generative_models import (
    ChatSession,
    Content,
    FunctionDeclaration,
    GenerationConfig,
    GenerationResponse,
    GenerativeModel,
    Part,
    Tool,
)

# %%
REGION = "us-central1"
PROJECT_ID='qwiklabs-asl-02-9dacbbe2194b'
DATASET_ID="project"

# %% [markdown]
# ## チャットセッション内にfunction calling 実装

# %%
class ChatAgent:
    def __init__(
        self,
        model: GenerativeModel,
        tool_handler_fn: Callable[[str, dict], Any],
        max_iterative_calls: int = 5,
    ):
        self.tool_handler_fn = tool_handler_fn
        self.chat_session = model.start_chat()
        self.max_iterative_calls = 5

    def send_message(self, message: str) -> GenerationResponse:
        response = self.chat_session.send_message(message)

        # This is None if a function call was not triggered
        fn_call = response.candidates[0].content.parts[0].function_call

        num_calls = 0
        # Reasoning loop. If fn_call is None then we never enter this
        # and simply return the response
        while fn_call:
            if num_calls > self.max_iterative_calls:
                break

            # Handle the function call
            fn_call_response = self.tool_handler_fn(
                fn_call.name, dict(fn_call.args)
            )
            num_calls += 1

            # Send the function call result back to the model
            response = self.chat_session.send_message(
                Part.from_function_response(
                    name=fn_call.name,
                    response={
                        "content": fn_call_response,
                    },
                ),
            )

            # If the response is another function call then we want to
            # stay in the reasoning loop and keep calling functions.
            fn_call = response.candidates[0].content.parts[0].function_call

        return response

# %% [markdown]
# ## 関数の定義

# %%
get_table_info_func = FunctionDeclaration(
    name="get_table_info",
    description="BigQuery テーブルとテーブルの説明を取得して、ユーザーの質問に適切に回答できるようにします。",
    parameters={
        "type": "object",
        "properties": {
            "table_id": {
                "type": "string",
                "description": "Fully qualified ID of BigQuery table",
            }
        },
    },
)

query_tool = Tool(
    function_declarations=[
        get_table_info_func,
    ],
)

# %%
client = bigquery.Client()
tables = client.list_tables(f"{PROJECT_ID}.{DATASET_ID}")
table_names = [table.table_id for table in tables]
print(table_names)

table_id_list=[]
for table_id in table_names:
    table_id_list.append(f"{PROJECT_ID}.{DATASET_ID}.{table_id}")
print(table_id_list)
# table_names = [table.table_id for table in tables]

# TABLE_ID_LIST=[]
# for table_id in table_names:
#     TABLE_ID_LIST.append(f"{PROJECT_ID}.{DATASET_ID}.{table_id}")
# Out:
# ['CIF別取引属性_個人', 'CRM_交渉履歴', 'VISAデビット契約情報', 'チャネル別利用状況', '保険元帳', '名寄せ取引属性_日次', '完済融資バッチキー', '定期預金元帳', '為替取引明細', '融資バッチキー', '融資ローン元帳']
# ['qwiklabs-asl-02-9dacbbe2194b.project.CIF別取引属性_個人', 'qwiklabs-asl-02-9dacbbe2194b.project.CRM_交渉履歴', 'qwiklabs-asl-02-9dacbbe2194b.project.VISAデビット契約情報', 'qwiklabs-asl-02-9dacbbe2194b.project.チャネル別利用状況', 'qwiklabs-asl-02-9dacbbe2194b.project.保険元帳', 'qwiklabs-asl-02-9dacbbe2194b.project.名寄せ取引属性_日次', 'qwiklabs-asl-02-9dacbbe2194b.project.完済融資バッチキー', 'qwiklabs-asl-02-9dacbbe2194b.project.定期預金元帳', 'qwiklabs-asl-02-9dacbbe2194b.project.為替取引明細', 'qwiklabs-asl-02-9dacbbe2194b.project.融資バッチキー', 'qwiklabs-asl-02-9dacbbe2194b.project.融資ローン元帳']

# %%
def get_table_info():
    bq_client = bigquery.Client()
    list_table_info=[]
    for table_id in table_id_list:
        list_table_info.append(bq_client.get_table(table_id).to_api_repr())
    return list_table_info

# %%
get_table_info()
# Out:
# [{'kind': 'bigquery#table',
#   'etag': 'yJXu2r1As2vX1aB8ynQyiA==',
#   'id': 'qwiklabs-asl-02-9dacbbe2194b:project.CIF別取引属性_個人',
#   'selfLink': 'https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/CIF別取引属性_個人',
#   'tableReference': {'projectId': 'qwiklabs-asl-02-9dacbbe2194b',
#    'datasetId': 'project',
#    'tableId': 'CIF別取引属性_個人'},
#   'schema': {},
#   'numBytes': '0',
#   'numLongTermBytes': '0',
#   'numRows': '0',
#   'creationTime': '1729217034949',
#   'lastModifiedTime': '1729217034995',
#   'type': 'TABLE',
#   'location': 'US',
#   'numTotalLogicalBytes': '0',
#   'numActiveLogicalBytes': '0',
#   'numLongTermLogicalBytes': '0'},
#  {'kind': 'bigquery#table',
#   'etag': 'yTQzHzsONbv3vrQjF9X83w==',
#   'id': 'qwiklabs-asl-02-9dacbbe2194b:project.CRM_交渉履歴',
#   'selfLink': 'https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/CRM_交渉履歴',
#   'tableReference': {'projectId': 'qwiklabs-asl-02-9dacbbe2194b',
#    'datasetId': 'project',
#    'tableId': 'CRM_交渉履歴'},
#   'schema': {},
#   'numBytes': '0',
#   'numLongTermBytes': '0',
#   'numRows': '0',
#   'creationTime': '1729217035179',
#   'lastModifiedTime': '1729217035226',
#   'type': 'TABLE',
#   'location': 'US',
#   'numTotalLogicalBytes': '0',
#   'numActiveLogicalBytes': '0',
#   'numLongTermLogicalBytes': '0'},
#  {'kind': 'bigquery#table',
#   'etag': '20+3norI0ROyoltohdqtBA==',
#   'id': 'qwiklabs-asl-02-9dacbbe2194b:project.VISAデビット契約情報',
#   'selfLink': 'https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/VISAデビット契約情報',
#   'tableReference': {'projectId': 'qwiklabs-asl-02-9dacbbe2194b',
#    'datasetId': 'project',
#    'tableId': 'VISAデビット契約情報'},
#   'schema': {},
#   'numBytes': '0',
#   'numLongTermBytes': '0',
#   'numRows': '0',
#   'creationTime': '1729217035440',
#   'lastModifiedTime': '1729217035495',
#   'type': 'TABLE',
#   'location': 'US',
#   'numTotalLogicalBytes': '0',
#   'numActiveLogicalBytes': '0',
#   'numLongTermLogicalBytes': '0'},
#  {'kind': 'bigquery#table',
#   'etag': 'iRPwVSKISQn0XQdZ7uCp2w==',
#   'id': 'qwiklabs-asl-02-9dacbbe2194b:project.チャネル別利用状況',
#   'selfLink': 'https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/チャネル別利用状況',
#   'tableReference': {'projectId': 'qwiklabs-asl-02-9dacbbe2194b',
#    'datasetId': 'project',
#    'tableId': 'チャネル別利用状況'},
#   'schema': {},
#   'numBytes': '0',
#   'numLongTermBytes': '0',
#   'numRows': '0',
#   'creationTime': '1729217035706',
#   'lastModifiedTime': '1729217035750',
#   'type': 'TABLE',
#   'location': 'US',
#   'numTotalLogicalBytes': '0',
#   'numActiveLogicalBytes': '0',
#   'numLongTermLogicalBytes': '0'},
#  {'kind': 'bigquery#table',
#   'etag': '4LHe3/cOB3OqFAVrxzArfg==',
#   'id': 'qwiklabs-asl-02-9dacbbe2194b:project.保険元帳',
#   'selfLink': 'https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/保険元帳',
#   'tableReference': {'projectId': 'qwiklabs-asl-02-9dacbbe2194b',
#    'datasetId': 'project',
#    'tableId': '保険元帳'},
#   'schema': {},
#   'numBytes': '0',
#   'numLongTermBytes': '0',
#   'numRows': '0',
#   'creationTime': '1729217035964',
#   'lastModifiedTime': '1729217036009',
#   'type': 'TABLE',
#   'location': 'US',
#   'numTotalLogicalBytes': '0',
#   'numActiveLogicalBytes': '0',
#   'numLongTermLogicalBytes': '0'},
#  {'kind': 'bigquery#table',
#   'etag': '/hhdx1OB2zVas9hT8WbweA==',
#   'id': 'qwiklabs-asl-02-9dacbbe2194b:project.名寄せ取引属性_日次',
#   'selfLink': 'https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/名寄せ取引属性_日次',
#   'tableReference': {'projectId': 'qwiklabs-asl-02-9dacbbe2194b',
#    'datasetId': 'project',
#    'tableId': '名寄せ取引属性_日次'},
#   'schema': {},
#   'numBytes': '0',
#   'numLongTermBytes': '0',
#   'numRows': '0',
#   'creationTime': '1729217036494',
#   'lastModifiedTime': '1729217036543',
#   'type': 'TABLE',
#   'location': 'US',
#   'numTotalLogicalBytes': '0',
#   'numActiveLogicalBytes': '0',
#   'numLongTermLogicalBytes': '0'},
#  {'kind': 'bigquery#table',
#   'etag': 'Pb/BS8b6oCNuIxGUsyj/yQ==',
#   'id': 'qwiklabs-asl-02-9dacbbe2194b:project.完済融資バッチキー',
#   'selfLink': 'https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/完済融資バッチキー',
#   'tableReference': {'projectId': 'qwiklabs-asl-02-9dacbbe2194b',
#    'datasetId': 'project',
#    'tableId': '完済融資バッチキー'},
#   'schema': {},
#   'numBytes': '0',
#   'numLongTermBytes': '0',
#   'numRows': '0',
#   'creationTime': '1729217036749',
#   'lastModifiedTime': '1729217036792',
#   'type': 'TABLE',
#   'location': 'US',
#   'numTotalLogicalBytes': '0',
#   'numActiveLogicalBytes': '0',
#   'numLongTermLogicalBytes': '0'},
#  {'kind': 'bigquery#table',
#   'etag': 'IAfTGylwB8PQ8Yq6hTtkYg==',
#   'id': 'qwiklabs-asl-02-9dacbbe2194b:project.定期預金元帳',
#   'selfLink': 'https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/定期預金元帳',
#   'tableReference': {'projectId': 'qwiklabs-asl-02-9dacbbe2194b',
#    'datasetId': 'project',
#    'tableId': '定期預金元帳'},
#   'schema': {},
#   'numBytes': '0',
#   'numLongTermBytes': '0',
#   'numRows': '0',
#   'creationTime': '1729217036954',
#   'lastModifiedTime': '1729217036980',
#   'type': 'TABLE',
#   'location': 'US',
#   'numTotalLogicalBytes': '0',
#   'numActiveLogicalBytes': '0',
#   'numLongTermLogicalBytes': '0'},
#  {'kind': 'bigquery#table',
#   'etag': 'qkp9y17/CIPl/DL4HOLdHQ==',
#   'id': 'qwiklabs-asl-02-9dacbbe2194b:project.為替取引明細',
#   'selfLink': 'https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/為替取引明細',
#   'tableReference': {'projectId': 'qwiklabs-asl-02-9dacbbe2194b',
#    'datasetId': 'project',
#    'tableId': '為替取引明細'},
#   'schema': {},
#   'numBytes': '0',
#   'numLongTermBytes': '0',
#   'numRows': '0',
#   'creationTime': '1729217037175',
#   'lastModifiedTime': '1729217037216',
#   'type': 'TABLE',
#   'location': 'US',
#   'numTotalLogicalBytes': '0',
#   'numActiveLogicalBytes': '0',
#   'numLongTermLogicalBytes': '0'},
#  {'kind': 'bigquery#table',
#   'etag': 'eRozYJiNjVJ7PTfAGD3ikg==',
#   'id': 'qwiklabs-asl-02-9dacbbe2194b:project.融資バッチキー',
#   'selfLink': 'https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/融資バッチキー',
#   'tableReference': {'projectId': 'qwiklabs-asl-02-9dacbbe2194b',
#    'datasetId': 'project',
#    'tableId': '融資バッチキー'},
#   'schema': {},
#   'numBytes': '0',
#   'numLongTermBytes': '0',
#   'numRows': '0',
#   'creationTime': '1729217037441',
#   'lastModifiedTime': '1729217037486',
#   'type': 'TABLE',
#   'location': 'US',
#   'numTotalLogicalBytes': '0',
#   'numActiveLogicalBytes': '0',
#   'numLongTermLogicalBytes': '0'},
#  {'kind': 'bigquery#table',
#   'etag': 'BuKKL/iu/b03SwwpcTEvtg==',
#   'id': 'qwiklabs-asl-02-9dacbbe2194b:project.融資ローン元帳',
#   'selfLink': 'https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/融資ローン元帳',
#   'tableReference': {'projectId': 'qwiklabs-asl-02-9dacbbe2194b',
#    'datasetId': 'project',
#    'tableId': '融資ローン元帳'},
#   'schema': {},
#   'numBytes': '0',
#   'numLongTermBytes': '0',
#   'numRows': '0',
#   'creationTime': '1729217037686',
#   'lastModifiedTime': '1729217037735',
#   'type': 'TABLE',
#   'location': 'US',
#   'numTotalLogicalBytes': '0',
#   'numActiveLogicalBytes': '0',
#   'numLongTermLogicalBytes': '0'}]

# %%
def handle_query_fn_call(fn_name: str, fn_args: dict):
    """Handles query tool function calls."""
    print(f"Function calling: {fn_name} with args: {str(fn_args)}\n")
    
    if fn_name == "get_table_info":
        result = get_table_info()
    else:
        raise ValueError(f"Unknown function call: {fn_name}")
    
    return result

# %%
model = GenerativeModel(
    "gemini-1.0-pro-001",
    tools=[query_tool],
    generation_config=GenerationConfig(temperature=0.0),
)
chat = ChatAgent(model=model, tool_handler_fn=handle_query_fn_call)

# %%
# Insert an initialization prompt before the first chat to help guide model behavior and output style/format

init_prompt = """
    質問には簡潔でわかりやすい回答をお願いします。
BigQuery テーブルをクエリして得た情報のみを使用してください。
情報を捏造しないでください。
    
    Question:
"""

prompt = "融資についてのテーブルの説明をしてください"
response = chat.send_message(init_prompt + prompt)
print(response.text)
# Out:
# Function calling: get_table_info with args: {'table_id': 'bigquery-public-data.usa_names.usa_1910_2013'}
#
# 申し訳ありませんが、このテーブルには融資に関する説明がありません。

# %%
chat.chat_session.history
# Out:
# [role: "user"
#  parts {
#    text: "\n    \350\263\252\345\225\217\343\201\253\343\201\257\347\260\241\346\275\224\343\201\247\343\202\217\343\201\213\343\202\212\343\202\204\343\201\231\343\201\204\345\233\236\347\255\224\343\202\222\343\201\212\351\241\230\343\201\204\343\201\227\343\201\276\343\201\231\343\200\202\nBigQuery \343\203\206\343\203\274\343\203\226\343\203\253\343\202\222\343\202\257\343\202\250\343\203\252\343\201\227\343\201\246\345\276\227\343\201\237\346\203\205\345\240\261\343\201\256\343\201\277\343\202\222\344\275\277\347\224\250\343\201\227\343\201\246\343\201\217\343\201\240\343\201\225\343\201\204\343\200\202\n\346\203\205\345\240\261\343\202\222\346\215\217\351\200\240\343\201\227\343\201\252\343\201\204\343\201\247\343\201\217\343\201\240\343\201\225\343\201\204\343\200\202\n    \n    Question:\n\350\236\215\350\263\207\343\201\253\343\201\244\343\201\204\343\201\246\343\201\256\343\203\206\343\203\274\343\203\226\343\203\253\343\201\256\350\252\254\346\230\216\343\202\222\343\201\227\343\201\246\343\201\217\343\201\240\343\201\225\343\201\204"
#  },
#  role: "model"
#  parts {
#    function_call {
#      name: "get_table_info"
#      args {
#        fields {
#          key: "table_id"
#          value {
#            string_value: "bigquery-public-data.usa_names.usa_1910_2013"
#          }
#        }
#      }
#    }
#  },
#  role: "user"
#  parts {
#    function_response {
#      name: "get_table_info"
#      response {
#        fields {
#          key: "content"
#          value {
#            list_value {
#              values {
#                struct_value {
#                  fields {
#                    key: "creationTime"
#                    value {
#                      string_value: "1729217034949"
#                    }
#                  }
#                  fields {
#                    key: "etag"
#                    value {
#                      string_value: "yJXu2r1As2vX1aB8ynQyiA=="
#                    }
#                  }
#                  fields {
#                    key: "id"
#                    value {
#                      string_value: "qwiklabs-asl-02-9dacbbe2194b:project.CIF\345\210\245\345\217\226\345\274\225\345\261\236\346\200\247_\345\200\213\344\272\272"
#                    }
#                  }
#                  fields {
#                    key: "kind"
#                    value {
#                      string_value: "bigquery#table"
#                    }
#                  }
#                  fields {
#                    key: "lastModifiedTime"
#                    value {
#                      string_value: "1729217034995"
#                    }
#                  }
#                  fields {
#                    key: "location"
#                    value {
#                      string_value: "US"
#                    }
#                  }
#                  fields {
#                    key: "numActiveLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numRows"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numTotalLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "schema"
#                    value {
#                      struct_value {
#                      }
#                    }
#                  }
#                  fields {
#                    key: "selfLink"
#                    value {
#                      string_value: "https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/CIF\345\210\245\345\217\226\345\274\225\345\261\236\346\200\247_\345\200\213\344\272\272"
#                    }
#                  }
#                  fields {
#                    key: "tableReference"
#                    value {
#                      struct_value {
#                        fields {
#                          key: "datasetId"
#                          value {
#                            string_value: "project"
#                          }
#                        }
#                        fields {
#                          key: "projectId"
#                          value {
#                            string_value: "qwiklabs-asl-02-9dacbbe2194b"
#                          }
#                        }
#                        fields {
#                          key: "tableId"
#                          value {
#                            string_value: "CIF\345\210\245\345\217\226\345\274\225\345\261\236\346\200\247_\345\200\213\344\272\272"
#                          }
#                        }
#                      }
#                    }
#                  }
#                  fields {
#                    key: "type"
#                    value {
#                      string_value: "TABLE"
#                    }
#                  }
#                }
#              }
#              values {
#                struct_value {
#                  fields {
#                    key: "creationTime"
#                    value {
#                      string_value: "1729217035179"
#                    }
#                  }
#                  fields {
#                    key: "etag"
#                    value {
#                      string_value: "yTQzHzsONbv3vrQjF9X83w=="
#                    }
#                  }
#                  fields {
#                    key: "id"
#                    value {
#                      string_value: "qwiklabs-asl-02-9dacbbe2194b:project.CRM_\344\272\244\346\270\211\345\261\245\346\255\264"
#                    }
#                  }
#                  fields {
#                    key: "kind"
#                    value {
#                      string_value: "bigquery#table"
#                    }
#                  }
#                  fields {
#                    key: "lastModifiedTime"
#                    value {
#                      string_value: "1729217035226"
#                    }
#                  }
#                  fields {
#                    key: "location"
#                    value {
#                      string_value: "US"
#                    }
#                  }
#                  fields {
#                    key: "numActiveLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numRows"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numTotalLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "schema"
#                    value {
#                      struct_value {
#                      }
#                    }
#                  }
#                  fields {
#                    key: "selfLink"
#                    value {
#                      string_value: "https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/CRM_\344\272\244\346\270\211\345\261\245\346\255\264"
#                    }
#                  }
#                  fields {
#                    key: "tableReference"
#                    value {
#                      struct_value {
#                        fields {
#                          key: "datasetId"
#                          value {
#                            string_value: "project"
#                          }
#                        }
#                        fields {
#                          key: "projectId"
#                          value {
#                            string_value: "qwiklabs-asl-02-9dacbbe2194b"
#                          }
#                        }
#                        fields {
#                          key: "tableId"
#                          value {
#                            string_value: "CRM_\344\272\244\346\270\211\345\261\245\346\255\264"
#                          }
#                        }
#                      }
#                    }
#                  }
#                  fields {
#                    key: "type"
#                    value {
#                      string_value: "TABLE"
#                    }
#                  }
#                }
#              }
#              values {
#                struct_value {
#                  fields {
#                    key: "creationTime"
#                    value {
#                      string_value: "1729217035440"
#                    }
#                  }
#                  fields {
#                    key: "etag"
#                    value {
#                      string_value: "20+3norI0ROyoltohdqtBA=="
#                    }
#                  }
#                  fields {
#                    key: "id"
#                    value {
#                      string_value: "qwiklabs-asl-02-9dacbbe2194b:project.VISA\343\203\207\343\203\223\343\203\203\343\203\210\345\245\221\347\264\204\346\203\205\345\240\261"
#                    }
#                  }
#                  fields {
#                    key: "kind"
#                    value {
#                      string_value: "bigquery#table"
#                    }
#                  }
#                  fields {
#                    key: "lastModifiedTime"
#                    value {
#                      string_value: "1729217035495"
#                    }
#                  }
#                  fields {
#                    key: "location"
#                    value {
#                      string_value: "US"
#                    }
#                  }
#                  fields {
#                    key: "numActiveLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numRows"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numTotalLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "schema"
#                    value {
#                      struct_value {
#                      }
#                    }
#                  }
#                  fields {
#                    key: "selfLink"
#                    value {
#                      string_value: "https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/VISA\343\203\207\343\203\223\343\203\203\343\203\210\345\245\221\347\264\204\346\203\205\345\240\261"
#                    }
#                  }
#                  fields {
#                    key: "tableReference"
#                    value {
#                      struct_value {
#                        fields {
#                          key: "datasetId"
#                          value {
#                            string_value: "project"
#                          }
#                        }
#                        fields {
#                          key: "projectId"
#                          value {
#                            string_value: "qwiklabs-asl-02-9dacbbe2194b"
#                          }
#                        }
#                        fields {
#                          key: "tableId"
#                          value {
#                            string_value: "VISA\343\203\207\343\203\223\343\203\203\343\203\210\345\245\221\347\264\204\346\203\205\345\240\261"
#                          }
#                        }
#                      }
#                    }
#                  }
#                  fields {
#                    key: "type"
#                    value {
#                      string_value: "TABLE"
#                    }
#                  }
#                }
#              }
#              values {
#                struct_value {
#                  fields {
#                    key: "creationTime"
#                    value {
#                      string_value: "1729217035706"
#                    }
#                  }
#                  fields {
#                    key: "etag"
#                    value {
#                      string_value: "iRPwVSKISQn0XQdZ7uCp2w=="
#                    }
#                  }
#                  fields {
#                    key: "id"
#                    value {
#                      string_value: "qwiklabs-asl-02-9dacbbe2194b:project.\343\203\201\343\203\243\343\203\215\343\203\253\345\210\245\345\210\251\347\224\250\347\212\266\346\263\201"
#                    }
#                  }
#                  fields {
#                    key: "kind"
#                    value {
#                      string_value: "bigquery#table"
#                    }
#                  }
#                  fields {
#                    key: "lastModifiedTime"
#                    value {
#                      string_value: "1729217035750"
#                    }
#                  }
#                  fields {
#                    key: "location"
#                    value {
#                      string_value: "US"
#                    }
#                  }
#                  fields {
#                    key: "numActiveLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numRows"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numTotalLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "schema"
#                    value {
#                      struct_value {
#                      }
#                    }
#                  }
#                  fields {
#                    key: "selfLink"
#                    value {
#                      string_value: "https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/\343\203\201\343\203\243\343\203\215\343\203\253\345\210\245\345\210\251\347\224\250\347\212\266\346\263\201"
#                    }
#                  }
#                  fields {
#                    key: "tableReference"
#                    value {
#                      struct_value {
#                        fields {
#                          key: "datasetId"
#                          value {
#                            string_value: "project"
#                          }
#                        }
#                        fields {
#                          key: "projectId"
#                          value {
#                            string_value: "qwiklabs-asl-02-9dacbbe2194b"
#                          }
#                        }
#                        fields {
#                          key: "tableId"
#                          value {
#                            string_value: "\343\203\201\343\203\243\343\203\215\343\203\253\345\210\245\345\210\251\347\224\250\347\212\266\346\263\201"
#                          }
#                        }
#                      }
#                    }
#                  }
#                  fields {
#                    key: "type"
#                    value {
#                      string_value: "TABLE"
#                    }
#                  }
#                }
#              }
#              values {
#                struct_value {
#                  fields {
#                    key: "creationTime"
#                    value {
#                      string_value: "1729217035964"
#                    }
#                  }
#                  fields {
#                    key: "etag"
#                    value {
#                      string_value: "4LHe3/cOB3OqFAVrxzArfg=="
#                    }
#                  }
#                  fields {
#                    key: "id"
#                    value {
#                      string_value: "qwiklabs-asl-02-9dacbbe2194b:project.\344\277\235\351\231\272\345\205\203\345\270\263"
#                    }
#                  }
#                  fields {
#                    key: "kind"
#                    value {
#                      string_value: "bigquery#table"
#                    }
#                  }
#                  fields {
#                    key: "lastModifiedTime"
#                    value {
#                      string_value: "1729217036009"
#                    }
#                  }
#                  fields {
#                    key: "location"
#                    value {
#                      string_value: "US"
#                    }
#                  }
#                  fields {
#                    key: "numActiveLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numRows"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numTotalLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "schema"
#                    value {
#                      struct_value {
#                      }
#                    }
#                  }
#                  fields {
#                    key: "selfLink"
#                    value {
#                      string_value: "https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/\344\277\235\351\231\272\345\205\203\345\270\263"
#                    }
#                  }
#                  fields {
#                    key: "tableReference"
#                    value {
#                      struct_value {
#                        fields {
#                          key: "datasetId"
#                          value {
#                            string_value: "project"
#                          }
#                        }
#                        fields {
#                          key: "projectId"
#                          value {
#                            string_value: "qwiklabs-asl-02-9dacbbe2194b"
#                          }
#                        }
#                        fields {
#                          key: "tableId"
#                          value {
#                            string_value: "\344\277\235\351\231\272\345\205\203\345\270\263"
#                          }
#                        }
#                      }
#                    }
#                  }
#                  fields {
#                    key: "type"
#                    value {
#                      string_value: "TABLE"
#                    }
#                  }
#                }
#              }
#              values {
#                struct_value {
#                  fields {
#                    key: "creationTime"
#                    value {
#                      string_value: "1729217036494"
#                    }
#                  }
#                  fields {
#                    key: "etag"
#                    value {
#                      string_value: "/hhdx1OB2zVas9hT8WbweA=="
#                    }
#                  }
#                  fields {
#                    key: "id"
#                    value {
#                      string_value: "qwiklabs-asl-02-9dacbbe2194b:project.\345\220\215\345\257\204\343\201\233\345\217\226\345\274\225\345\261\236\346\200\247_\346\227\245\346\254\241"
#                    }
#                  }
#                  fields {
#                    key: "kind"
#                    value {
#                      string_value: "bigquery#table"
#                    }
#                  }
#                  fields {
#                    key: "lastModifiedTime"
#                    value {
#                      string_value: "1729217036543"
#                    }
#                  }
#                  fields {
#                    key: "location"
#                    value {
#                      string_value: "US"
#                    }
#                  }
#                  fields {
#                    key: "numActiveLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numRows"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numTotalLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "schema"
#                    value {
#                      struct_value {
#                      }
#                    }
#                  }
#                  fields {
#                    key: "selfLink"
#                    value {
#                      string_value: "https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/\345\220\215\345\257\204\343\201\233\345\217\226\345\274\225\345\261\236\346\200\247_\346\227\245\346\254\241"
#                    }
#                  }
#                  fields {
#                    key: "tableReference"
#                    value {
#                      struct_value {
#                        fields {
#                          key: "datasetId"
#                          value {
#                            string_value: "project"
#                          }
#                        }
#                        fields {
#                          key: "projectId"
#                          value {
#                            string_value: "qwiklabs-asl-02-9dacbbe2194b"
#                          }
#                        }
#                        fields {
#                          key: "tableId"
#                          value {
#                            string_value: "\345\220\215\345\257\204\343\201\233\345\217\226\345\274\225\345\261\236\346\200\247_\346\227\245\346\254\241"
#                          }
#                        }
#                      }
#                    }
#                  }
#                  fields {
#                    key: "type"
#                    value {
#                      string_value: "TABLE"
#                    }
#                  }
#                }
#              }
#              values {
#                struct_value {
#                  fields {
#                    key: "creationTime"
#                    value {
#                      string_value: "1729217036749"
#                    }
#                  }
#                  fields {
#                    key: "etag"
#                    value {
#                      string_value: "Pb/BS8b6oCNuIxGUsyj/yQ=="
#                    }
#                  }
#                  fields {
#                    key: "id"
#                    value {
#                      string_value: "qwiklabs-asl-02-9dacbbe2194b:project.\345\256\214\346\270\210\350\236\215\350\263\207\343\203\220\343\203\203\343\203\201\343\202\255\343\203\274"
#                    }
#                  }
#                  fields {
#                    key: "kind"
#                    value {
#                      string_value: "bigquery#table"
#                    }
#                  }
#                  fields {
#                    key: "lastModifiedTime"
#                    value {
#                      string_value: "1729217036792"
#                    }
#                  }
#                  fields {
#                    key: "location"
#                    value {
#                      string_value: "US"
#                    }
#                  }
#                  fields {
#                    key: "numActiveLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numRows"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numTotalLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "schema"
#                    value {
#                      struct_value {
#                      }
#                    }
#                  }
#                  fields {
#                    key: "selfLink"
#                    value {
#                      string_value: "https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/\345\256\214\346\270\210\350\236\215\350\263\207\343\203\220\343\203\203\343\203\201\343\202\255\343\203\274"
#                    }
#                  }
#                  fields {
#                    key: "tableReference"
#                    value {
#                      struct_value {
#                        fields {
#                          key: "datasetId"
#                          value {
#                            string_value: "project"
#                          }
#                        }
#                        fields {
#                          key: "projectId"
#                          value {
#                            string_value: "qwiklabs-asl-02-9dacbbe2194b"
#                          }
#                        }
#                        fields {
#                          key: "tableId"
#                          value {
#                            string_value: "\345\256\214\346\270\210\350\236\215\350\263\207\343\203\220\343\203\203\343\203\201\343\202\255\343\203\274"
#                          }
#                        }
#                      }
#                    }
#                  }
#                  fields {
#                    key: "type"
#                    value {
#                      string_value: "TABLE"
#                    }
#                  }
#                }
#              }
#              values {
#                struct_value {
#                  fields {
#                    key: "creationTime"
#                    value {
#                      string_value: "1729217036954"
#                    }
#                  }
#                  fields {
#                    key: "etag"
#                    value {
#                      string_value: "IAfTGylwB8PQ8Yq6hTtkYg=="
#                    }
#                  }
#                  fields {
#                    key: "id"
#                    value {
#                      string_value: "qwiklabs-asl-02-9dacbbe2194b:project.\345\256\232\346\234\237\351\240\220\351\207\221\345\205\203\345\270\263"
#                    }
#                  }
#                  fields {
#                    key: "kind"
#                    value {
#                      string_value: "bigquery#table"
#                    }
#                  }
#                  fields {
#                    key: "lastModifiedTime"
#                    value {
#                      string_value: "1729217036980"
#                    }
#                  }
#                  fields {
#                    key: "location"
#                    value {
#                      string_value: "US"
#                    }
#                  }
#                  fields {
#                    key: "numActiveLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numRows"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numTotalLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "schema"
#                    value {
#                      struct_value {
#                      }
#                    }
#                  }
#                  fields {
#                    key: "selfLink"
#                    value {
#                      string_value: "https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/\345\256\232\346\234\237\351\240\220\351\207\221\345\205\203\345\270\263"
#                    }
#                  }
#                  fields {
#                    key: "tableReference"
#                    value {
#                      struct_value {
#                        fields {
#                          key: "datasetId"
#                          value {
#                            string_value: "project"
#                          }
#                        }
#                        fields {
#                          key: "projectId"
#                          value {
#                            string_value: "qwiklabs-asl-02-9dacbbe2194b"
#                          }
#                        }
#                        fields {
#                          key: "tableId"
#                          value {
#                            string_value: "\345\256\232\346\234\237\351\240\220\351\207\221\345\205\203\345\270\263"
#                          }
#                        }
#                      }
#                    }
#                  }
#                  fields {
#                    key: "type"
#                    value {
#                      string_value: "TABLE"
#                    }
#                  }
#                }
#              }
#              values {
#                struct_value {
#                  fields {
#                    key: "creationTime"
#                    value {
#                      string_value: "1729217037175"
#                    }
#                  }
#                  fields {
#                    key: "etag"
#                    value {
#                      string_value: "qkp9y17/CIPl/DL4HOLdHQ=="
#                    }
#                  }
#                  fields {
#                    key: "id"
#                    value {
#                      string_value: "qwiklabs-asl-02-9dacbbe2194b:project.\347\202\272\346\233\277\345\217\226\345\274\225\346\230\216\347\264\260"
#                    }
#                  }
#                  fields {
#                    key: "kind"
#                    value {
#                      string_value: "bigquery#table"
#                    }
#                  }
#                  fields {
#                    key: "lastModifiedTime"
#                    value {
#                      string_value: "1729217037216"
#                    }
#                  }
#                  fields {
#                    key: "location"
#                    value {
#                      string_value: "US"
#                    }
#                  }
#                  fields {
#                    key: "numActiveLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numRows"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numTotalLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "schema"
#                    value {
#                      struct_value {
#                      }
#                    }
#                  }
#                  fields {
#                    key: "selfLink"
#                    value {
#                      string_value: "https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/\347\202\272\346\233\277\345\217\226\345\274\225\346\230\216\347\264\260"
#                    }
#                  }
#                  fields {
#                    key: "tableReference"
#                    value {
#                      struct_value {
#                        fields {
#                          key: "datasetId"
#                          value {
#                            string_value: "project"
#                          }
#                        }
#                        fields {
#                          key: "projectId"
#                          value {
#                            string_value: "qwiklabs-asl-02-9dacbbe2194b"
#                          }
#                        }
#                        fields {
#                          key: "tableId"
#                          value {
#                            string_value: "\347\202\272\346\233\277\345\217\226\345\274\225\346\230\216\347\264\260"
#                          }
#                        }
#                      }
#                    }
#                  }
#                  fields {
#                    key: "type"
#                    value {
#                      string_value: "TABLE"
#                    }
#                  }
#                }
#              }
#              values {
#                struct_value {
#                  fields {
#                    key: "creationTime"
#                    value {
#                      string_value: "1729217037441"
#                    }
#                  }
#                  fields {
#                    key: "etag"
#                    value {
#                      string_value: "eRozYJiNjVJ7PTfAGD3ikg=="
#                    }
#                  }
#                  fields {
#                    key: "id"
#                    value {
#                      string_value: "qwiklabs-asl-02-9dacbbe2194b:project.\350\236\215\350\263\207\343\203\220\343\203\203\343\203\201\343\202\255\343\203\274"
#                    }
#                  }
#                  fields {
#                    key: "kind"
#                    value {
#                      string_value: "bigquery#table"
#                    }
#                  }
#                  fields {
#                    key: "lastModifiedTime"
#                    value {
#                      string_value: "1729217037486"
#                    }
#                  }
#                  fields {
#                    key: "location"
#                    value {
#                      string_value: "US"
#                    }
#                  }
#                  fields {
#                    key: "numActiveLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numRows"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numTotalLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "schema"
#                    value {
#                      struct_value {
#                      }
#                    }
#                  }
#                  fields {
#                    key: "selfLink"
#                    value {
#                      string_value: "https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/\350\236\215\350\263\207\343\203\220\343\203\203\343\203\201\343\202\255\343\203\274"
#                    }
#                  }
#                  fields {
#                    key: "tableReference"
#                    value {
#                      struct_value {
#                        fields {
#                          key: "datasetId"
#                          value {
#                            string_value: "project"
#                          }
#                        }
#                        fields {
#                          key: "projectId"
#                          value {
#                            string_value: "qwiklabs-asl-02-9dacbbe2194b"
#                          }
#                        }
#                        fields {
#                          key: "tableId"
#                          value {
#                            string_value: "\350\236\215\350\263\207\343\203\220\343\203\203\343\203\201\343\202\255\343\203\274"
#                          }
#                        }
#                      }
#                    }
#                  }
#                  fields {
#                    key: "type"
#                    value {
#                      string_value: "TABLE"
#                    }
#                  }
#                }
#              }
#              values {
#                struct_value {
#                  fields {
#                    key: "creationTime"
#                    value {
#                      string_value: "1729217037686"
#                    }
#                  }
#                  fields {
#                    key: "etag"
#                    value {
#                      string_value: "BuKKL/iu/b03SwwpcTEvtg=="
#                    }
#                  }
#                  fields {
#                    key: "id"
#                    value {
#                      string_value: "qwiklabs-asl-02-9dacbbe2194b:project.\350\236\215\350\263\207\343\203\255\343\203\274\343\203\263\345\205\203\345\270\263"
#                    }
#                  }
#                  fields {
#                    key: "kind"
#                    value {
#                      string_value: "bigquery#table"
#                    }
#                  }
#                  fields {
#                    key: "lastModifiedTime"
#                    value {
#                      string_value: "1729217037735"
#                    }
#                  }
#                  fields {
#                    key: "location"
#                    value {
#                      string_value: "US"
#                    }
#                  }
#                  fields {
#                    key: "numActiveLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numLongTermLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numRows"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "numTotalLogicalBytes"
#                    value {
#                      string_value: "0"
#                    }
#                  }
#                  fields {
#                    key: "schema"
#                    value {
#                      struct_value {
#                      }
#                    }
#                  }
#                  fields {
#                    key: "selfLink"
#                    value {
#                      string_value: "https://bigquery.googleapis.com/bigquery/v2/projects/qwiklabs-asl-02-9dacbbe2194b/datasets/project/tables/\350\236\215\350\263\207\343\203\255\343\203\274\343\203\263\345\205\203\345\270\263"
#                    }
#                  }
#                  fields {
#                    key: "tableReference"
#                    value {
#                      struct_value {
#                        fields {
#                          key: "datasetId"
#                          value {
#                            string_value: "project"
#                          }
#                        }
#                        fields {
#                          key: "projectId"
#                          value {
#                            string_value: "qwiklabs-asl-02-9dacbbe2194b"
#                          }
#                        }
#                        fields {
#                          key: "tableId"
#                          value {
#                            string_value: "\350\236\215\350\263\207\343\203\255\343\203\274\343\203\263\345\205\203\345\270\263"
#                          }
#                        }
#                      }
#                    }
#                  }
#                  fields {
#                    key: "type"
#                    value {
#                      string_value: "TABLE"
#                    }
#                  }
#                }
#              }
#            }
#          }
#        }
#      }
#    }
#  },
#  role: "model"
#  parts {
#    text: "\347\224\263\343\201\227\350\250\263\343\201\202\343\202\212\343\201\276\343\201\233\343\202\223\343\201\214\343\200\201\343\201\223\343\201\256\343\203\206\343\203\274\343\203\226\343\203\253\343\201\253\343\201\257\350\236\215\350\263\207\343\201\253\351\226\242\343\201\231\343\202\213\350\252\254\346\230\216\343\201\214\343\201\202\343\202\212\343\201\276\343\201\233\343\202\223\343\200\202"
#  }]
